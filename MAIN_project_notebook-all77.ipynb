# %% [markdown]
# # Analyzing Public Sentiments of Chicago Neighborhoods
#
# What is the relationship between neighborhood reputation and context?
# Below I explore this question in the context of Chicago, IL, using social media (Twitter) data and socioeconomic data for each neighborhood.
# For this analysis I define "neighborhood" as one of Chicago's 77 community areas, which are officially recognized by the City of Chicago.
# I measure neighborhood reputation based on the sentiment of each tweet that refers to a neighborhood by name (e.g., "Hyde Park").
#
# Eventually I'll expand this to mapping the tweets and examining the data for potential correlations with other types of data such as socioeconomics, crime, and types of amenities.

# %% [markdown]
# # Step 0: Set up
#
# Importing relevant modules and keys

# %%
import time
import pandas as pd
pd.set_option('display.max_colwidth', -1)  # this helps show as much of the tweets in the dataframes as possible

# %%
import nltk
# in command line, pip install twython 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# in terminal: easy_install pip
# in terminal: pip install tweepy
# in terminal: pip install --upgrade pip [per suggestion shown inside terminal]
import tweepy

# %%
# These four codes constitute your authorization to extract data from Twitter
consumer_token = 'qZMmvxcPLfwCixedks1m3jXGg'
consumer_secret = 'UFFyLdOlePodkPYvR6NR64N0SVinVsPezNb1IKg1hNXl06jy67'
access_token = '2382930698-0eCycGIeqv4SUmOvSINQbkhnb2v9hTPDlSpcb8q'
access_token_secret = 'eTmMeL9pj7pcxoupFDqDuNmzWSXUn8UQWrYeYAcKu8xyR'

# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_token, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Creation of the actual interface, using authentication
# api = tweepy.API(auth)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
#%matplotlib inline
#import matplotlib.pyplot as plt
#import datetime

# %% [markdown]
# # Step 1: Get the data
#
# Downloading, cleaning up, and storing Twitter data in a csv file.

# %% [markdown]
# <h4>Create and save raw dataset (ds) 1:</h4>
#
# Criteria:
# 1. list of tweets within last 6-9 days.
#   * This time range limit is set by Twitter, see https://dev.twitter.com/rest/public/search
# 2. tweet mentions "englewood"
#   * FYI there are two Community Areas inside Chicago with "Englewood" in the name. They're located adjacent to each other. There are also "Englewood" in other states, such as NJ.
# 3. tweet originates within 15 miles of Chicago, IL
#   * Determine this by using geocoding of tweets
#   * Identify geocode for Chicago by clicking on latitude/longitude info on Chicago wikipedia page: https://en.wikipedia.org/wiki/Chicago
# 4. tweet is in English

# %%
api.rate_limit_status('search')  # checks the status of my search request limit
# Out:
# {'rate_limit_context': {'access_token': '2382930698-0eCycGIeqv4SUmOvSINQbkhnb2v9hTPDlSpcb8q'},
#  'resources': {'search': {'/search/tweets': {'limit': 180,
#     'remaining': 169,
#     'reset': 1481655307}}}}

# %%
# establish datasets or "buckets" into which each relevant data point is going to be appended:
community_area_name_ds1 = []
user_screen_name_ds1 = []
user_location_ds1 = []  
user_followers_count_ds1 = []
tweet_coordinates_ds1 = []
tweet_date_time_ds1 = [] 
tweet_content_ds1 = [] 
tweet_num_retweet_ds1 = [] 
tweet_num_liked_ds1 = []

for tweet in tweepy.Cursor(api.search,
                           q = 'englewood',
                           lang = 'en', 
#                           geocode = '41.836944,-87.684722,15mi').items(10):
                           geocode = '41.836944,-87.684722,15mi').items():
    community_area_name_ds1.append('Englewood')
    user_screen_name_ds1.append(tweet.user.screen_name)
    user_location_ds1.append(tweet.user.location)
    user_followers_count_ds1.append(tweet.user.followers_count)
    tweet_coordinates_ds1.append(tweet.coordinates)
    tweet_date_time_ds1.append(tweet.created_at)
    tweet_content_ds1.append(tweet.text)
    tweet_num_retweet_ds1.append(tweet.retweet_count)
    tweet_num_liked_ds1.append(tweet.favorite_count)

df1 = pd.DataFrame({
        "Community Area Mentioned": community_area_name_ds1,
        "User Screen Name": user_screen_name_ds1,
        "User Location": user_location_ds1,
        "User Number of Followers":user_followers_count_ds1,
        "Tweet Coordinates": tweet_coordinates_ds1,
        "Tweet Day and Time": tweet_date_time_ds1,
        "Tweet Number of Times Retweeted": tweet_num_retweet_ds1,
        "Tweet Number of Times Liked": tweet_num_liked_ds1,
        "Tweet Content": tweet_content_ds1})

# %%
df1.shape
# Out:
# (964, 9)

# %%
#df1[0:3]

# %%
df1.to_csv('df1_raw_data.csv')

# %% [markdown]
# <h4>Create and save raw dataset (ds) 2:</h4>
#
# Criteria:
# 1. list of tweets within last 6-9 days.
# 2. tweet mentions one of Chicago's 77 community areas
# 3. tweet originates within 15 miles of Chicago, IL
# 4. tweet is in English

# %%
# for list of community area names, importing csv file
SES = pd.read_csv('https://raw.githubusercontent.com/yarikan/final_project_in_progress/master/Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv?token=AQAvwPu3y_8vQZSH9YaxBCH2d7QLk3KOks5YWXU0wA%3D%3D')
SES = SES.dropna()
# SES
# SES.columns
SES['COMMUNITY AREA NAME'][0:5]
# Out:
# 0    Rogers Park
# 1    West Ridge
# 2    Uptown
# 3    Lincoln Square
# 4    North Center
# Name: COMMUNITY AREA NAME, dtype: object

# %%
api.rate_limit_status('search')  # checks the status of my search request limit
# Out:
# {'rate_limit_context': {'access_token': '2382930698-0eCycGIeqv4SUmOvSINQbkhnb2v9hTPDlSpcb8q'},
#  'resources': {'search': {'/search/tweets': {'limit': 180,
#     'remaining': 169,
#     'reset': 1481655307}}}}

# %%
community_area_name_ds2 = []
user_screen_name_ds2 = []
user_location_ds2 = []  
user_followers_count_ds2 = []
tweet_coordinates_ds2 = []
tweet_date_time_ds2 = [] 
tweet_content_ds2 = [] 
tweet_num_retweet_ds2 = [] 
tweet_num_liked_ds2 = []

for name in SES['COMMUNITY AREA NAME']:
    time.sleep(20)  # suspends execution of the current thread for this many seconds
    for tweet in tweepy.Cursor(api.search,
                           q = name,
                           lang = 'en', 
#                           geocode = '41.836944,-87.684722,15mi').items(10):
                           geocode = '41.836944,-87.684722,15mi').items():
        community_area_name_ds2.append(name.lower())
        user_screen_name_ds2.append(tweet.user.screen_name)
        user_location_ds2.append(tweet.user.location)
        user_followers_count_ds2.append(tweet.user.followers_count)
        tweet_coordinates_ds2.append(tweet.coordinates)
        tweet_date_time_ds2.append(tweet.created_at)
        tweet_content_ds2.append(tweet.text)
        tweet_num_retweet_ds2.append(tweet.retweet_count)
        tweet_num_liked_ds2.append(tweet.favorite_count)

df2 = pd.DataFrame({
        "Community Area Mentioned": community_area_name_ds2,
        "User Screen Name": user_screen_name_ds2,
        "User Location": user_location_ds2,
        "User Number of Followers":user_followers_count_ds2,
        "Tweet Coordinates": tweet_coordinates_ds2,
        "Tweet Day and Time": tweet_date_time_ds2,
        "Tweet Number of Times Retweeted": tweet_num_retweet_ds2,
        "Tweet Number of Times Liked": tweet_num_liked_ds2,
        "Tweet Content": tweet_content_ds2})

# %%
df2.shape
#df2[0:3]
#df2.to_csv('df2_raw_data.csv')

# %% [markdown]
# # Step 2: Apply sentiment analysis to tweets

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/yarikan/final_project_in_progress/master/df1_raw_data.csv?token=AQAvwAvWcbuCGIeknomQgS0IPKZmQ_1Rks5YVX7OwA%3D%3D')
df2 = pd.read_csv('')

# %%
#df1.columns
df2.columns
# Out:
# Index(['Unnamed: 0', 'Community Area Mentioned', 'Tweet Content',
#        'Tweet Coordinates', 'Tweet Day and Time',
#        'Tweet Number of Times Liked', 'Tweet Number of Times Retweeted',
#        'User Location', 'User Number of Followers', 'User Screen Name'],
#       dtype='object')

# %%
analyzer = SentimentIntensityAnalyzer()
#df1["Sentiment"] = df1['Tweet Content'].apply(lambda tweet: analyzer.polarity_scores(tweet))
df2["Sentiment"] = df2['Tweet Content'].apply(lambda tweet: analyzer.polarity_scores(tweet))

# %%
#df1[0:1]
df2[0:1]
# Out:
#    Unnamed: 0 Community Area Mentioned  \
# 0  0           Englewood
#
#                                                                                                                                    Tweet Content  \
# 0  Plz help us give a toy 2 a kid in Englewood 4 Xmas\n312-576-2391 we will pick up donations or deliver them to Xperie… https://t.co/OAy0SNqhiU
#
#   Tweet Coordinates   Tweet Day and Time  Tweet Number of Times Liked  \
# 0  NaN               2016-12-12 20:36:08  0
#
#    Tweet Number of Times Retweeted       User Location  \
# 0  0                                Englewood, Chicago
#
#    User Number of Followers User Screen Name  \
# 0  601                       mystrogrant
#
#                                                       Sentiment
# 0  {'pos': 0.174, 'compound': 0.4588, 'neg': 0.0, 'neu': 0.826}

# %%
#df1.Sentiment[0]
#df1['Sentiment'][0]
df2['Sentiment'][0]

# The following examples demonstrate the value of the compound score:
# VADER is smart, handsome, and funny. {'neg': 0.0, 'neu': 0.254, 'pos': 0.746, 'compound': 0.8316} 
# VADER is smart, handsome, and funny! {'neg': 0.0, 'neu': 0.248, 'pos': 0.752, 'compound': 0.8439} 
# VADER is very smart, handsome, and funny. {'neg': 0.0, 'neu': 0.299, 'pos': 0.701, 'compound': 0.8545} 
# VADER is VERY SMART, handsome, and FUNNY. {'neg': 0.0, 'neu': 0.246, 'pos': 0.754, 'compound': 0.9227} 
# VADER is VERY SMART, handsome, and FUNNY!!! {'neg': 0.0, 'neu': 0.233, 'pos': 0.767, 'compound': 0.9342} 
# VADER is VERY SMART, really handsome, and INCREDIBLY FUNNY!!! {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.9469}
# Out:
# {'compound': 0.4588, 'neg': 0.0, 'neu': 0.826, 'pos': 0.174}

# %%
#print(type(df1['Sentiment'][0]))
print(type(df2['Sentiment'][0]))
# Out:
# <class 'dict'>

# %%
# convert to string
#df1['Sentiment'] = df1['Sentiment'].apply(str)
df2['Sentiment'] = df2['Sentiment'].apply(str)

# %%
#print(type(df1['Sentiment'][0]))
print(type(df2['Sentiment'][0]))
# Out:
# <class 'str'>

# %% [markdown]
# <h4>Extracting sentiment compound scores as additional column</h4>

# %%
#df1_temp = df1['Sentiment'].str.split(',').apply(pd.Series)
#df1_temp[0:5]

df2_temp = df2['Sentiment'].str.split(',').apply(pd.Series)
df2_temp[0:5]
# Out:
#                0                     1              2               3
# 0  {'pos': 0.174   'compound': 0.4588    'neg': 0.0     'neu': 0.826}
# 1  {'pos': 0.113   'compound': -0.6124   'neg': 0.351   'neu': 0.536}
# 2  {'pos': 0.107   'compound': -0.6124   'neg': 0.331   'neu': 0.562}
# 3  {'pos': 0.0     'compound': -0.802    'neg': 0.507   'neu': 0.493}
# 4  {'pos': 0.0     'compound': -0.802    'neg': 0.474   'neu': 0.526}

# %%
#df1_temp[1][0:5]
df2_temp[1][0:5]
# Out:
# 0     'compound': 0.4588
# 1     'compound': -0.6124
# 2     'compound': -0.6124
# 3     'compound': -0.802
# 4     'compound': -0.802
# Name: 1, dtype: object

# %%
#left_split = df1_temp[1].str.split(': ').apply(pd.Series)
#left_split[1][0:5]

left_split = df2_temp[1].str.split(': ').apply(pd.Series)
left_split[1][0:5]
# Out:
# 0    0.4588
# 1    -0.6124
# 2    -0.6124
# 3    -0.802
# 4    -0.802
# Name: 1, dtype: object

# %%
#compound = left_split[1].apply(float)
#df1['Compound Sentiment Score'] = compound

compound = left_split[1].apply(float)
df2['Compound Sentiment Score'] = compound

# %%
#df1[0:5]
df2[0:5]
# Out:
#    Unnamed: 0 Community Area Mentioned  \
# 0  0           Englewood
# 1  1           Englewood
# 2  2           Englewood
# 3  3           Englewood
# 4  4           Englewood
#
#                                                                                                                                    Tweet Content  \
# 0  Plz help us give a toy 2 a kid in Englewood 4 Xmas\n312-576-2391 we will pick up donations or deliver them to Xperie… https://t.co/OAy0SNqhiU
# 1  Pay Family Of Man Killed By Cops $2.34M, Finance Committee Recommends https://t.co/lW19FdWMsw
# 2  Pay Family Of Man Killed By Cops $2.34M, Finance Committee Recommends https://t.co/pFOWw1uNwc https://t.co/1ZB0ZJsqzE
# 3  Man killed in Englewood shooting, crash identified https://t.co/u4zp50KKYz #chicago
# 4  Man killed in Englewood shooting, crash identified... #news #Chicago https://t.co/gOxJDsJOiB
#
#   Tweet Coordinates   Tweet Day and Time  Tweet Number of Times Liked  \
# 0  NaN               2016-12-12 20:36:08  0
# 1  NaN               2016-12-12 20:33:17  0
# 2  NaN               2016-12-12 20:33:08  0
# 3  NaN               2016-12-12 20:30:07  0
# 4  NaN               2016-12-12 20:28:02  0
#
#    Tweet Number of Times Retweeted       User Location  \
# 0  0                                Englewood, Chicago
# 1  0                                Chicago, IL
# 2  0                                Chicago, IL
# 3  0                                Chicago, Illinois
# 4  0                                Chicago, IL
#
#    User Number of Followers User Screen Name  \
# 0  601                       mystrogrant
# 1  215                       CosbyChicago
# 2  111                       BurtFuji
# 3  19150                     chicagonewsnow
# 4  127                       GeosNewsChicago
#
#                                                          Sentiment  \
# 0  {'pos': 0.174, 'compound': 0.4588, 'neg': 0.0, 'neu': 0.826}
# 1  {'pos': 0.113, 'compound': -0.6124, 'neg': 0.351, 'neu': 0.536}
# 2  {'pos': 0.107, 'compound': -0.6124, 'neg': 0.331, 'neu': 0.562}
# 3  {'pos': 0.0, 'compound': -0.802, 'neg': 0.507, 'neu': 0.493}
# 4  {'pos': 0.0, 'compound': -0.802, 'neg': 0.474, 'neu': 0.526}
#
#    Compound Sentiment Score
# 0  0.4588
# 1 -0.6124
# 2 -0.6124
# 3 -0.8020
# 4 -0.8020

# %%
#df1.to_csv('df1_wCompound.csv')
df2.to_csv('df2_wCompound.csv')

# %% [markdown]
# # Step 3: Descriptive Statistics

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/yarikan/final_project_in_progress/master/df1_wCompound.csv?token=AQAvwAyoKxP3pVfAj5BdS7tCHl1C4B6Vks5YWCR_wA%3D%3D')
df2 = pd.read_csv('')

# %%
#df1.columns
df2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Community Area Mentioned',
#        'Tweet Content', 'Tweet Coordinates', 'Tweet Day and Time',
#        'Tweet Number of Times Liked', 'Tweet Number of Times Retweeted',
#        'User Location', 'User Number of Followers', 'User Screen Name',
#        'Sentiment', 'Compound Sentiment Score'],
#       dtype='object')

# %%
#del df1['Unnamed: 0']
#del df1['Unnamed: 0.1']
#df1['Count 1'] = 1

del df2['Unnamed: 0']
del df2['Unnamed: 0.1']
df2['Count 1'] = 1

# %%
#df1.shape
df2.shape
# Out:
# (964, 12)

# %%
# computing an index for neighborhood sentiment:
# for the purpose of this exercise, I assume that followers, users who "like" a tweet, and users who retweet it 
# each play an additive role in tweet influence. I consider their impact separately below even though in reality 
# they may overlap in terms of users.

# compound sentiment score * user number of followers = exposure1 
#df1['User to Follower Diffusion'] = df1['Compound Sentiment Score']*df1['User Number of Followers']
df2['User to Follower Diffusion'] = df2['Compound Sentiment Score']*df2['User Number of Followers']

# compound sentiment score * tweet number of likes = exposure2
#df1['User to Liker Diffusion'] = df1['Compound Sentiment Score']*df1['Tweet Number of Times Liked']
df2['User to Liker Diffusion'] = df2['Compound Sentiment Score']*df2['Tweet Number of Times Liked']

# compound sentiment score * tweet number of retweeted = exposure3
#df1['User to Retweeter Diffusion'] = df1['Compound Sentiment Score']*df1['Tweet Number of Times Retweeted']
df2['User to Retweeter Diffusion'] = df2['Compound Sentiment Score']*df2['Tweet Number of Times Retweeted']

# exposure1 + exposure2 + exposure3 = total level of diffussion of ONE tweet's sentiment, tweet may or may not be a retweet of another 
#df1['Tweet Sentiment Total Diffusion'] = df1['User to Follower Diffusion'] + df1['User to Liker Diffusion'] + df1['User to Retweeter Diffusion']
df2['Tweet Sentiment Total Diffusion'] = df2['User to Follower Diffusion'] + df2['User to Liker Diffusion'] + df2['User to Retweeter Diffusion']

# %%
#df1[0:5]
df2[0:5]

# %%
# total number of tweets per neighborhood:

#tweet_by_neighb = df1.groupby('Community Area Mentioned')
#tweet_total_by_neighb_num = tweet_by_neighb['Community Area Mentioned'].agg('count')
#tweet_total_by_neighb_num

#tweet_by_neighb = df1.groupby('Community Area Mentioned')
tweet_by_neighb = df2.groupby('Community Area Mentioned')

# total number of positive tweets:
total_tweet_by_neighb_pos_num = tweet_by_neighb.apply(lambda x: x[x['Compound Sentiment Score'] > 0]['Count 1'].sum())
# total number of negative tweets:
total_tweet_by_neighb_neg_num = tweet_by_neighb.apply(lambda x: x[x['Compound Sentiment Score'] < 0]['Count 1'].sum())
# total number of neutral tweets:
total_tweet_by_neighb_neu_num = tweet_by_neighb.apply(lambda x: x[x['Compound Sentiment Score'] == 0]['Count 1'].sum())
# total number of tweets:
total_tweet_by_neighb_num = total_tweet_by_neighb_pos_num + total_tweet_by_neighb_neg_num + total_tweet_by_neighb_neu_num

print(total_tweet_by_neighb_pos_num)
print(total_tweet_by_neighb_neg_num)
print(total_tweet_by_neighb_neu_num)
print(total_tweet_by_neighb_num)
# Out:
# Community Area Mentioned
# Englewood    243
# dtype: int64
# Community Area Mentioned
# Englewood    379
# dtype: int64
# Community Area Mentioned
# Englewood    342
# dtype: int64
# Community Area Mentioned
# Englewood    964
# dtype: int64

# %%
a = total_tweet_by_neighb_pos_num
b = total_tweet_by_neighb_neg_num

s = 'Regarding this neighborhood there are a total of ' + repr(x) + 'positive sentiment tweets, and ' + repr(y) + 'negative sentiment tweets.'
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-21ce2abc3b7c> in <module>()
# ----> 1 a = total_tweet_by_neighb_pos_num
#       2 b = total_tweet_by_neighb_neg_num
#       3
#       4 s = 'Regarding this neighborhood there are a total of ' + repr(x) + 'positive sentiment tweets, and ' + repr(y) + 'negative sentiment tweets.'
#       5 print(s)
#
# NameError: name 'total_tweet_by_neighb_pos_num' is not defined

# %%
# for Englewood and West Englewood neighborhoods, there are 342 neutral tweets in the dataset
# below, visually examine tweets that score zero in compoound sentiment
# because question is whether to ignore all neutral tweets or integrate them into the index computation

#df1[df1['Compound Sentiment Score'] == 0]
df2[df2['Compound Sentiment Score'] == 0]

# Sample neutral tweets below suggest that the neutrality in part is real (e.g., "Just posted a photo @ Englewood")
# as well as due to the quality of the tool (e.g., "Boy, 16, shot in West Englewood" should have scored negative sentiment)
# Sample positive tweets (df1[df1['Compound Sentiment Score'] > 0]) suggest the sentiment tool does very well with positive tweets.
# Sample negative tweets suggest the tool isn't as good with identifying the sentiment as it is with positive ones (e.g., "RT @DNAinfoCHI: My Block, My Hood, My City gather volunteers from across the city to shovel snow in Englewood after weekend storm" should have been classified positive).

# THEREFORE, to keep things simple for this exercise, 
# I proceed below to compute a reputation index that entirely excludes all neutral-sentiment tweets.
# Out:
#     Community Area Mentioned  \
# 8    Englewood
# 9    Englewood
# 13   Englewood
# 18   Englewood
# 30   Englewood
# 32   Englewood
# 40   Englewood
# 48   Englewood
# 49   Englewood
# 51   Englewood
# 56   Englewood
# 61   Englewood
# 86   Englewood
# 93   Englewood
# 94   Englewood
# 96   Englewood
# 97   Englewood
# 98   Englewood
# 99   Englewood
# 100  Englewood
# 102  Englewood
# 104  Englewood
# 105  Englewood
# 106  Englewood
# 107  Englewood
# 108  Englewood
# 109  Englewood
# 110  Englewood
# 111  Englewood
# 113  Englewood
# ..         ...
# 780  Englewood
# 782  Englewood
# 783  Englewood
# 784  Englewood
# 799  Englewood
# 810  Englewood
# 848  Englewood
# 849  Englewood
# 850  Englewood
# 860  Englewood
# 866  Englewood
# 867  Englewood
# 880  Englewood
# 884  Englewood
# 887  Englewood
# 894  Englewood
# 895  Englewood
# 896  Englewood
# 897  Englewood
# 912  Englewood
# 918  Englewood
# 924  Englewood
# 926  Englewood
# 932  Englewood
# 933  Englewood
# 944  Englewood
# 957  Englewood
# 958  Englewood
# 961  Englewood
# 962  Englewood
#
#                                                                                                                                             Tweet Content  \
# 8    Fund brings ‘Quality of Life’ to Englewood https://t.co/z7WViMcvlq via @CCChronicle
# 9    @EricDickerson for Rams head coach! 👍🏽🙌🏽👊🏽
# 13   Boy, 16, shot in West Englewood.. Related Articles: https://t.co/CcepPXDo92
# 18   Aye, I'm tryna be a millionaire overnight so I can transform Englewood into the new black wall street. To donate: https://t.co/BgKDbdBboS
# 30   TEAM Englewood https://t.co/UbWQX4re80
# 32   Retweeted MetroFamily Services (@MetroFamChicago):\n\n#Englewood entreprenuers: Pitch your business plan Thursday... https://t.co/DSs0dLJqGl
# 40   Just posted a photo @ Englewood, Chicago https://t.co/jR9LiSqPcQ
# 48   RT @Elevate_Energy: Elevators Pete &amp; Tim visited Johnson Prep in #Englewood! Students discussed #smartgrid, #buildingscience, &amp; saving ener…
# 49   RT @ThePublicLeague: Something to prove: Undefeated Urban Prep-Englewood aims for the Red-South https://t.co/lKkNPMCSOC https://t.co/7Ah63r…
# 51   englewood, chicago https://t.co/6jclG8xclU
# 56   Researching on resident-led development plans and came across this image for the site of the Englewood Whole Foods. https://t.co/UoArEZ5aDN
# 61   Boy, 16, shot in West Englewood.. Related Articles: https://t.co/CcepPXDo92
# 86   RT @Join_RAGE: We already have the snow now we need the lights! Come out to see the lighting of the Englewood Christmas Tree... https://t.c…
# 93   RT @Join_RAGE: We already have the snow now we need the lights! Come out to see the lighting of the Englewood Christmas Tree... https://t.c…
# 94   We already have the snow now we need the lights! Come out to see the lighting of the Englewood Christmas Tree... https://t.co/vW6QElzC4G
# 96   Just posted a photo @ Englewood, Chicago https://t.co/tq9eVa8i9W
# 97   Just posted a photo @ Englewood, Chicago https://t.co/5JjbQFohzE
# 98   Just posted a photo @ Englewood, Chicago https://t.co/RPccAhOZeJ
# 99   Just posted a photo @ Englewood, Chicago https://t.co/i1hyxCul5W
# 100  Just posted a photo @ Englewood, Chicago https://t.co/eJK579qEFO
# 102  The Godfather 🤘🏿🎸💍❤️️👅😍💍🙌🏾👑👠🎒💄💋👔👖 @ New Englewood Terrace Appartments https://t.co/de1bGTeJGw
# 104  Daddy harder then any of you nigga's🤘🏿🎸😘😍😍😬😈😡😝🍎💍💍😝😁🍧🍧🌶🍦🍦🍦🍦🍦 @ Englewood, Chicago https://t.co/MYMRHLovMi
# 105  Just posted a photo @ New Englewood Terrace Appartments https://t.co/g6Cb2XLYIj
# 106  Just posted a photo @ Englewood, Chicago https://t.co/7EqJkU2XCu
# 107  Just posted a photo @ Englewood, Chicago https://t.co/LXQkMIJMNY
# 108  Just posted a photo @ New Englewood Terrace Appartments https://t.co/LZIicvYukt
# 109  Just posted a photo @ Englewood, Chicago https://t.co/29CMEmHySB
# 110  Whole Body Associate Team Leader Englewood Jobs in Chicago, IL #Chicago #IL #jobs #jobsearch https://t.co/NOtl2cyVFM
# 111  Kayla grandma live in Englewood 🤔 everything is making so much sense now
# 113  I got one, it's called Homies in Englewood 🙄😂 https://t.co/yclIdalyho
# ..                                                                     ...
# 780  RT @VoiceOfChicago: Last night... #Englewood &amp; #Offthestreetclub Neighborhood choirs sang about #peace &amp; #justice #ccc #chicagochildrenscho…
# 782  RT @VoiceOfChicago: Last night... #Englewood &amp; #Offthestreetclub Neighborhood choirs sang about #peace &amp; #justice #ccc #chicagochildrenscho…
# 783  RT @VoiceOfChicago: Last night... #Englewood &amp; #Offthestreetclub Neighborhood choirs sang about #peace &amp; #justice #ccc #chicagochildrenscho…
# 784  RT @VoiceOfChicago: Last night... #Englewood &amp; #Offthestreetclub Neighborhood choirs sang about #peace &amp; #justice #ccc #chicagochildrenscho…
# 799  RT @VoiceOfChicago: Last night... #Englewood &amp; #Offthestreetclub Neighborhood choirs sang about #peace &amp; #justice #ccc #chicagochildrenscho…
# 810  that cracka was in Englewood so you know what that's about
# 848  Retweeted Englewood Portal (@EnglewoodPortal):\n\nThe Englewood Quality of Life Business Plan Competition enters... https://t.co/2ObFqxsgDo
# 849  RT @EnglewoodPortal: The Englewood Quality of Life Business Plan Competition enters its final phase on Thursday. December 15 with a... http…
# 850  📷 Splash #ChyKyd #chitown #Englewood Cakey ain’t I https://t.co/ul6rbOoegz
# 860  RT @VoiceOfChicago: Last night... #Englewood &amp; #Offthestreetclub Neighborhood choirs sang about #peace &amp; #justice #ccc #chicagochildrenscho…
# 866  RT @LaurenceWHolmes: We ain't forgot... @ Englewood, Chicago https://t.co/v1BW9Jvawp
# 867  Last night... #Englewood &amp; #Offthestreetclub Neighborhood choirs sang about #peace &amp; #justice #ccc… https://t.co/CR0X75euVK
# 880  Beer Wine Buyer Englewood Jobs in Chicago, IL #Chicago #IL #jobs #jobsearch https://t.co/gDmVFqVuzB
# 884  I'm at West Englewood in Chicago, IL https://t.co/OAezGrLVb3
# 887  RT @LaurenceWHolmes: We ain't forgot... @ Englewood, Chicago https://t.co/v1BW9Jvawp
# 894  RT @LaurenceWHolmes: We ain't forgot... @ Englewood, Chicago https://t.co/v1BW9Jvawp
# 895  My squad....#TheLifeofMrsEnglewood https://t.co/VLNio9jgmV
# 896  RT @LaurenceWHolmes: We ain't forgot... @ Englewood, Chicago https://t.co/v1BW9Jvawp
# 897  We ain't forgot... @ Englewood, Chicago https://t.co/v1BW9Jvawp
# 912  @TheeSouthside what part of englewood is this?
# 918  @CubNationAngry englewood I'll wear it too.
# 924  RT @EnglewoodPortal: The Englewood Quality of Life Business Plan Competition enters its final phase on Thursday. December 15 with a... http…
# 926  Just posted a photo @ Englewood, Chicago https://t.co/fBT52ut0Jk
# 932  RT @EnglewoodPortal: The Englewood Quality of Life Business Plan Competition enters its final phase on Thursday. December 15 with a... http…
# 933  The Englewood Quality of Life Business Plan Competition enters its final phase on Thursday. December 15 with a... https://t.co/NRAemhwQ1O
# 944  #CarGoals @ Englewood, Chicago https://t.co/9WxUplI7nH
# 957  Just posted a photo @ Englewood, Chicago https://t.co/CQX25sOTSM
# 958  The Latter @ Englewood, Chicago https://t.co/pDAeGvLExE
# 961  Let's get this Saturday started! #TheLifeofMrsEnglewood #SpinClass @ Cycle Therapy https://t.co/cxbAtE41Hb
# 962  That's the sauce darling...Happy Saturday! #TheLifeofMrsEnglewood https://t.co/FJtSDPMl3p
#
#                                                  Tweet Coordinates  \
# 8    NaN
# 9    NaN
# 13   NaN
# 18   NaN
# 30   NaN
# 32   NaN
# 40   {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 48   NaN
# 49   NaN
# 51   NaN
# 56   NaN
# 61   NaN
# 86   NaN
# 93   NaN
# 94   NaN
# 96   {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 97   {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 98   {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 99   {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 100  {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 102  {'type': 'Point', 'coordinates': [-87.6402899, 41.77711]}
# 104  {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 105  {'type': 'Point', 'coordinates': [-87.6402899, 41.77711]}
# 106  {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 107  {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 108  {'type': 'Point', 'coordinates': [-87.6402899, 41.77711]}
# 109  {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 110  NaN
# 111  NaN
# 113  NaN
# ..   ...
# 780  NaN
# 782  NaN
# 783  NaN
# 784  NaN
# 799  NaN
# 810  NaN
# 848  NaN
# 849  NaN
# 850  NaN
# 860  NaN
# 866  NaN
# 867  NaN
# 880  NaN
# 884  {'type': 'Point', 'coordinates': [-87.66740099, 41.78105097]}
# 887  NaN
# 894  NaN
# 895  NaN
# 896  NaN
# 897  NaN
# 912  NaN
# 918  NaN
# 924  NaN
# 926  {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 932  NaN
# 933  NaN
# 944  {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 957  NaN
# 958  {'type': 'Point', 'coordinates': [-87.64477778, 41.77978611]}
# 961  {'type': 'Point', 'coordinates': [-87.59400803, 41.80924095]}
# 962  NaN
#
#       Tweet Day and Time  Tweet Number of Times Liked  \
# 8    2016-12-12 19:56:13  0
# 9    2016-12-12 19:50:57  0
# 13   2016-12-12 19:12:45  0
# 18   2016-12-12 18:00:30  0
# 30   2016-12-12 15:34:54  0
# 32   2016-12-12 14:51:32  0
# 40   2016-12-12 12:58:24  0
# 48   2016-12-12 02:32:34  0
# 49   2016-12-12 02:30:41  0
# 51   2016-12-12 01:29:30  1
# 56   2016-12-11 23:29:48  0
# 61   2016-12-11 22:12:37  0
# 86   2016-12-11 17:37:12  0
# 93   2016-12-11 14:57:07  0
# 94   2016-12-11 14:49:23  3
# 96   2016-12-11 13:46:47  0
# 97   2016-12-11 13:34:07  0
# 98   2016-12-11 13:33:57  0
# 99   2016-12-11 13:33:43  0
# 100  2016-12-11 13:30:40  0
# 102  2016-12-11 13:07:44  0
# 104  2016-12-11 13:03:49  0
# 105  2016-12-11 12:54:12  0
# 106  2016-12-11 12:54:02  0
# 107  2016-12-11 12:53:49  0
# 108  2016-12-11 12:53:35  0
# 109  2016-12-11 12:53:26  0
# 110  2016-12-11 11:04:13  0
# 111  2016-12-11 08:14:21  0
# 113  2016-12-11 07:55:37  0
# ..                   ... ..
# 780  2016-12-05 04:25:49  0
# 782  2016-12-05 04:21:32  0
# 783  2016-12-05 04:20:00  0
# 784  2016-12-05 04:19:36  0
# 799  2016-12-05 00:55:17  0
# 810  2016-12-05 00:06:49  0
# 848  2016-12-04 18:44:41  0
# 849  2016-12-04 18:44:37  0
# 850  2016-12-04 18:43:18  8
# 860  2016-12-04 16:35:55  0
# 866  2016-12-04 15:45:03  0
# 867  2016-12-04 15:40:02  37
# 880  2016-12-04 08:40:46  0
# 884  2016-12-04 05:29:01  0
# 887  2016-12-04 04:59:54  0
# 894  2016-12-04 04:35:44  0
# 895  2016-12-04 04:21:45  0
# 896  2016-12-04 04:21:39  0
# 897  2016-12-04 04:19:49  16
# 912  2016-12-04 02:22:04  0
# 918  2016-12-04 00:00:11  0
# 924  2016-12-03 22:14:59  0
# 926  2016-12-03 21:55:58  0
# 932  2016-12-03 21:12:10  0
# 933  2016-12-03 21:10:12  1
# 944  2016-12-03 19:55:43  1
# 957  2016-12-03 16:01:42  0
# 958  2016-12-03 15:57:43  0
# 961  2016-12-03 15:07:10  0
# 962  2016-12-03 14:45:57  0
#
#      Tweet Number of Times Retweeted       User Location  \
# 8    0                                Englewood, Chicago
# 9    0                                Chicago, IL
# 13   0                                Chicago, IL
# 18   0                                Chicago
# 30   0                                Chicago, IL
# 32   0                                Blue Island, IL
# 40   0                                New Mexico
# 48   1                                Chicago Illinois
# 49   34                               NaN
# 51   0                                Chicago, IL
# 56   0                                Chicago,Il
# 61   0                                Chicago, IL
# 86   2                                Detroit, MI
# 93   2                                Chicago, IL
# 94   2                                Englewood, Chicago
# 96   0                                 GYM FLOW
# 97   0                                 GYM FLOW
# 98   0                                 GYM FLOW
# 99   0                                 GYM FLOW
# 100  0                                 GYM FLOW
# 102  0                                 GYM FLOW
# 104  0                                 GYM FLOW
# 105  0                                 GYM FLOW
# 106  0                                 GYM FLOW
# 107  0                                 GYM FLOW
# 108  0                                 GYM FLOW
# 109  0                                 GYM FLOW
# 110  0                                Chicago, IL
# 111  0                                Chicago, IL
# 113  0                                Chicago, IL
# ..  ..                                        ...
# 780  18                               Fort Wayne, IN
# 782  18                               NaN
# 783  18                               NaN
# 784  18                               San Francisco
# 799  18                               Usually in my head
# 810  0                                Chicago
# 848  0                                Englewood, Chicago
# 849  3                                Englewood, Chicago
# 850  0                                Chicago, IL
# 860  18                               NaN
# 866  4                                NaN
# 867  18                               Chicago, IL
# 880  0                                Chicago, IL
# 884  0                                NaN
# 887  4                                NaN
# 894  4                                Providence, RI
# 895  0                                Englewood, Chicago
# 896  4                                Chicago, IL
# 897  4                                Chicago, IL
# 912  0                                Chicago
# 918  0                                Chicago, Illinois
# 924  3                                Chicago, IL
# 926  0                                Chicago, IL
# 932  3                                Chicago, IL
# 933  3                                Chicago
# 944  0                                chi town
# 957  0                                Chicago, IL
# 958  0                                Chicago, Ill
# 961  0                                Englewood, Chicago
# 962  0                                Englewood, Chicago
#
#      User Number of Followers User Screen Name  \
# 8    2105                      Join_RAGE
# 9    255                       englewood_23
# 13   417                       chicago_update
# 18   4889                      gabebritton
# 30   564                       Jammelah_
# 32   19                        BIRCommunity
# 40   64                        Soujaboy27
# 48   246                       PDeMay1
# 49   306                       justtuniquee
# 51   625                       yayahollaback
# 56   192                       negateandnull
# 61   417                       chicago_update
# 86   244                       carmelswift
# 93   362                       jwanhall
# 94   2105                      Join_RAGE
# 96   440                       VON_GotIt
# 97   440                       VON_GotIt
# 98   440                       VON_GotIt
# 99   440                       VON_GotIt
# 100  440                       VON_GotIt
# 102  440                       VON_GotIt
# 104  440                       VON_GotIt
# 105  440                       VON_GotIt
# 106  440                       VON_GotIt
# 107  440                       VON_GotIt
# 108  440                       VON_GotIt
# 109  440                       VON_GotIt
# 110  784                       careersiftchi
# 111  900                       YA_TuSabes
# 113  900                       YA_TuSabes
# ..   ...                              ...
# 780  139                       ABranesample
# 782  164                       MolliAnnMonroe
# 783  74                        QmanLynch
# 784  81686                     michaelfranti
# 799  40                        doc_norwood
# 810  14845                     Mr1738
# 848  2105                      Join_RAGE
# 849  2105                      Join_RAGE
# 850  10700                     ChyKyd_Rockz
# 860  880                       josephineslee
# 866  26                        tbone36jav
# 867  1235                      VoiceOfChicago
# 880  784                       careersiftchi
# 884  444                       Jglendab
# 887  110                       HOOS13R
# 894  119                       Rodzilla0279
# 895  1358                      mrs_englewood
# 896  491                       kwandarykitten
# 897  59501                     LaurenceWHolmes
# 912  1169                      TrilliamClinton
# 918  1978                      82packfan
# 924  1014                      ashchicago6
# 926  405                       DanaDane84
# 932  2016                      shelleystern
# 933  569                       EnglewoodPortal
# 944  2470                      solow74
# 957  403                       antgmoore
# 958  307                       ZaphnathPaanea
# 961  1358                      mrs_englewood
# 962  1358                      mrs_englewood
#
#                                                  Sentiment  \
# 8    {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 9    {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 13   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 18   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 30   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 32   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 40   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 48   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 49   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 51   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 56   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 61   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 86   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 93   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 94   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 96   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 97   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 98   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 99   {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 100  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 102  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 104  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 105  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 106  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 107  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 108  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 109  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 110  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 111  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 113  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# ..                                                     ...
# 780  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 782  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 783  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 784  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 799  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 810  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 848  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 849  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 850  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 860  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 866  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 867  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 880  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 884  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 887  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 894  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 895  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 896  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 897  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 912  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 918  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 924  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 926  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 932  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 933  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 944  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 957  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 958  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 961  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
# 962  {'compound': 0.0, 'neu': 1.0, 'neg': 0.0, 'pos': 0.0}
#
#      Compound Sentiment Score  Count 1  User to Follower Diffusion  \
# 8    0.0                       1        0.0
# 9    0.0                       1        0.0
# 13   0.0                       1        0.0
# 18   0.0                       1        0.0
# 30   0.0                       1        0.0
# 32   0.0                       1        0.0
# 40   0.0                       1        0.0
# 48   0.0                       1        0.0
# 49   0.0                       1        0.0
# 51   0.0                       1        0.0
# 56   0.0                       1        0.0
# 61   0.0                       1        0.0
# 86   0.0                       1        0.0
# 93   0.0                       1        0.0
# 94   0.0                       1        0.0
# 96   0.0                       1        0.0
# 97   0.0                       1        0.0
# 98   0.0                       1        0.0
# 99   0.0                       1        0.0
# 100  0.0                       1        0.0
# 102  0.0                       1        0.0
# 104  0.0                       1        0.0
# 105  0.0                       1        0.0
# 106  0.0                       1        0.0
# 107  0.0                       1        0.0
# 108  0.0                       1        0.0
# 109  0.0                       1        0.0
# 110  0.0                       1        0.0
# 111  0.0                       1        0.0
# 113  0.0                       1        0.0
# ..   ...                      ..        ...
# 780  0.0                       1        0.0
# 782  0.0                       1        0.0
# 783  0.0                       1        0.0
# 784  0.0                       1        0.0
# 799  0.0                       1        0.0
# 810  0.0                       1        0.0
# 848  0.0                       1        0.0
# 849  0.0                       1        0.0
# 850  0.0                       1        0.0
# 860  0.0                       1        0.0
# 866  0.0                       1        0.0
# 867  0.0                       1        0.0
# 880  0.0                       1        0.0
# 884  0.0                       1        0.0
# 887  0.0                       1        0.0
# 894  0.0                       1        0.0
# 895  0.0                       1        0.0
# 896  0.0                       1        0.0
# 897  0.0                       1        0.0
# 912  0.0                       1        0.0
# 918  0.0                       1        0.0
# 924  0.0                       1        0.0
# 926  0.0                       1        0.0
# 932  0.0                       1        0.0
# 933  0.0                       1        0.0
# 944  0.0                       1        0.0
# 957  0.0                       1        0.0
# 958  0.0                       1        0.0
# 961  0.0                       1        0.0
# 962  0.0                       1        0.0
#
#      User to Liker Diffusion  User to Retweeter Diffusion  \
# 8    0.0                      0.0
# 9    0.0                      0.0
# 13   0.0                      0.0
# 18   0.0                      0.0
# 30   0.0                      0.0
# 32   0.0                      0.0
# 40   0.0                      0.0
# 48   0.0                      0.0
# 49   0.0                      0.0
# 51   0.0                      0.0
# 56   0.0                      0.0
# 61   0.0                      0.0
# 86   0.0                      0.0
# 93   0.0                      0.0
# 94   0.0                      0.0
# 96   0.0                      0.0
# 97   0.0                      0.0
# 98   0.0                      0.0
# 99   0.0                      0.0
# 100  0.0                      0.0
# 102  0.0                      0.0
# 104  0.0                      0.0
# 105  0.0                      0.0
# 106  0.0                      0.0
# 107  0.0                      0.0
# 108  0.0                      0.0
# 109  0.0                      0.0
# 110  0.0                      0.0
# 111  0.0                      0.0
# 113  0.0                      0.0
# ..   ...                      ...
# 780  0.0                      0.0
# 782  0.0                      0.0
# 783  0.0                      0.0
# 784  0.0                      0.0
# 799  0.0                      0.0
# 810  0.0                      0.0
# 848  0.0                      0.0
# 849  0.0                      0.0
# 850  0.0                      0.0
# 860  0.0                      0.0
# 866  0.0                      0.0
# 867  0.0                      0.0
# 880  0.0                      0.0
# 884  0.0                      0.0
# 887  0.0                      0.0
# 894  0.0                      0.0
# 895  0.0                      0.0
# 896  0.0                      0.0
# 897  0.0                      0.0
# 912  0.0                      0.0
# 918  0.0                      0.0
# 924  0.0                      0.0
# 926  0.0                      0.0
# 932  0.0                      0.0
# 933  0.0                      0.0
# 944  0.0                      0.0
# 957  0.0                      0.0
# 958  0.0                      0.0
# 961  0.0                      0.0
# 962  0.0                      0.0
#
#      Tweet Sentiment Total Diffusion
# 8    0.0
# 9    0.0
# 13   0.0
# 18   0.0
# 30   0.0
# 32   0.0
# 40   0.0
# 48   0.0
# 49   0.0
# 51   0.0
# 56   0.0
# 61   0.0
# 86   0.0
# 93   0.0
# 94   0.0
# 96   0.0
# 97   0.0
# 98   0.0
# 99   0.0
# 100  0.0
# 102  0.0
# 104  0.0
# 105  0.0
# 106  0.0
# 107  0.0
# 108  0.0
# 109  0.0
# 110  0.0
# 111  0.0
# 113  0.0
# ..   ...
# 780  0.0
# 782  0.0
# 783  0.0
# 784  0.0
# 799  0.0
# 810  0.0
# 848  0.0
# 849  0.0
# 850  0.0
# 860  0.0
# 866  0.0
# 867  0.0
# 880  0.0
# 884  0.0
# 887  0.0
# 894  0.0
# 895  0.0
# 896  0.0
# 897  0.0
# 912  0.0
# 918  0.0
# 924  0.0
# 926  0.0
# 932  0.0
# 933  0.0
# 944  0.0
# 957  0.0
# 958  0.0
# 961  0.0
# 962  0.0
#
# [342 rows x 16 columns]

# %%
total_tweet_by_neighb_pos_infl = 0
total_tweet_by_neighb_neg_infl = 0

#for score in df1['Compound Sentiment Score']:
for score in df2['Compound Sentiment Score']:
    if score > 0:
        total_tweet_by_neighb_pos_infl += score
    if score < 0:
        total_tweet_by_neighb_neg_infl += score

print(total_tweet_by_neighb_pos_infl)
print(total_tweet_by_neighb_neg_infl)
# Out:
# 121.6472
# -184.4313

# %% [markdown]
# <h4>Computing weighted sum of sentiments per neighborhood, giving more weight to negative tweets </h4>
# Based on HBR article (Folkman, Jack Zenger and Joseph. 2013. “The Ideal Praise-to-Criticism Ratio.” Harvard Business Review. March 15. https://hbr.org/2013/03/the-ideal-praise-to-criticism.), ideal praise-to-criticism ratio = 5-6 positive comments for every negative one: assume 5 positive for every 1 negative.

# %%
avg_neg = total_tweet_by_neighb_neg_infl / total_tweet_by_neighb_neg_num
avg_pos = total_tweet_by_neighb_pos_infl / total_tweet_by_neighb_pos_num

# %%
reputation_index = ((5*avg_neg)+avg_pos) / 6
reputation_index
# Out:
# Community Area Mentioned
# Englewood   -0.322087
# dtype: float64
