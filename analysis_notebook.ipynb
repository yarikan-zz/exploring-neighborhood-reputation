# %% [markdown]
# # CHIsentiment: Exploring Public Sentiments of Chicago Neighborhoods
#
# What is the relationship between the reputation and the characteristics of a neighborhood?
# Below I explore this question in the context of Chicago, IL, using social media (Twitter) data and a dataset of socioeconomic data per neighborhood available from the City of Chicago data portal (https://data.cityofchicago.org). For this exploration, a "neighborhood" is defined as one of Chicago's 77 community areas, which are officially recognized by the City of Chicago. I model neighborhood reputation as an index summarizing the sentiment of tweets mentioning a given neighborhood (more details provided as I work my way through the question).
#
# I proceed in the following steps:
# * Set up (import modules and keys that I'll need along the way)
# * Construct dataset
#     * Download relevant Twitter data
#     * Apply sentiment analysis to tweets
#     * Generate neighborhood reputation index scores for each neighborhood
#     * Put socioeconomic and Twitter data per neighborhood into one table
# * Develop descriptive statistics
# * Develop inferential statistics
# * Conclusions

# %% [markdown]
# # Set up
#
# Importing relevant modules and keys

# %%
import time

import pandas as pd
pd.set_option('display.max_colwidth', -1)  # this helps show as much of the tweets in the dataframes as possible

# %matplotlib inline
#import matplotlib.pyplot as plt

# %%
# in terminal: easy_install pip
# in terminal: pip install tweepy
# in terminal: pip install --upgrade pip [per suggestion shown inside terminal]
import tweepy

import nltk
# in command line, pip install twython 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# These four codes constitute your authorization to extract data from Twitter
consumer_token = 'please'
consumer_secret = 'use'
access_token = 'your'
access_token_secret = 'own'

# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_token, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Creation of the actual interface, using authentication
# api = tweepy.API(auth)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# # Construct dataset
#
# <h3>Downloading, cleaning up, and storing Twitter data in a csv file</h3>

# %% [markdown]
# Dataset Criteria:
# 1. list of tweets within last 6-9 days.
#   * This time range limit is set by Twitter, see https://dev.twitter.com/rest/public/search
# 2. tweet mentions one of Chicago's 77 community areas
#   * FYI there are two Community Areas inside Chicago with "Englewood" in the name. They're located adjacent to each other. There are also "Englewood" in other states, such as NJ.
# 3. tweet originates within 15 miles of Chicago, IL
#   * Determine this by using geocoding of tweets
#   * Identify geocode for Chicago by clicking on latitude/longitude info on Chicago wikipedia page: https://en.wikipedia.org/wiki/Chicago
# 4. tweet is in English

# %%
# import table with column of community area names
SES = pd.read_csv('Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv')
SES = SES.dropna()  # do this so that the last row is dropped, which shows totals for whole city
#SES
#SES.columns
SES['COMMUNITY AREA NAME']
# Out:
# 0     Rogers Park
# 1     West Ridge
# 2     Uptown
# 3     Lincoln Square
# 4     North Center
# 5     Lake View
# 6     Lincoln Park
# 7     Near North Side
# 8     Edison Park
# 9     Norwood Park
# 10    Jefferson Park
# 11    Forest Glen
# 12    North Park
# 13    Albany Park
# 14    Portage Park
# 15    Irving Park
# 16    Dunning
# 17    Montclaire
# 18    Belmont Cragin
# 19    Hermosa
# 20    Avondale
# 21    Logan Square
# 22    Humboldt park
# 23    West Town
# 24    Austin
# 25    West Garfield Park
# 26    East Garfield Park
# 27    Near West Side
# 28    North Lawndale
# 29    South Lawndale
#            ...
# 47    Calumet Heights
# 48    Roseland
# 49    Pullman
# 50    South Deering
# 51    East Side
# 52    West Pullman
# 53    Riverdale
# 54    Hegewisch
# 55    Garfield Ridge
# 56    Archer Heights
# 57    Brighton Park
# 58    McKinley Park
# 59    Bridgeport
# 60    New City
# 61    West Elsdon
# 62    Gage Park
# 63    Clearing
# 64    West Lawn
# 65    Chicago Lawn
# 66    West Englewood
# 67    Englewood
# 68    Greater Grand Crossing
# 69    Ashburn
# 70    Auburn Gresham
# 71    Beverly
# 72    Washington Height
# 73    Mount Greenwood
# 74    Morgan Park
# 75    O'Hare
# 76    Edgewater
# Name: COMMUNITY AREA NAME, dtype: object

# %%
# check the status of my search request limit
api.rate_limit_status('search')
# Out:
# {'rate_limit_context': {'access_token': '2382930698-0eCycGIeqv4SUmOvSINQbkhnb2v9hTPDlSpcb8q'},
#  'resources': {'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1481679991}}}}

# %%
# establish lists or "buckets" into which each relevant data point is going to be appended:
community_area_name_list = []
user_screen_name_list = []
user_location_list = []  
user_followers_count_list = []
tweet_coordinates_list = []
tweet_date_time_list = [] 
tweet_content_list = [] 
tweet_num_retweet_list = [] 
tweet_num_liked_list = []

# caution, the following takes a very long time

for name in SES['COMMUNITY AREA NAME']:
    time.sleep(60)  # suspends execution of the current thread for this many seconds
    for tweet in tweepy.Cursor(api.search,
                           q = name,
                           lang = 'en', 
#                           geocode = '41.836944,-87.684722,15mi').items(10):
                           geocode = '41.836944,-87.684722,15mi').items():
        community_area_name_list.append(name.lower())
        user_screen_name_list.append(tweet.user.screen_name)
        user_location_list.append(tweet.user.location)
        user_followers_count_list.append(tweet.user.followers_count)
        tweet_coordinates_list.append(tweet.coordinates)
        tweet_date_time_list.append(tweet.created_at)
        tweet_content_list.append(tweet.text)
        tweet_num_retweet_list.append(tweet.retweet_count)
        tweet_num_liked_list.append(tweet.favorite_count)

df = pd.DataFrame({
        "Community Area Mentioned": community_area_name_list,
        "User Screen Name": user_screen_name_list,
        "User Location": user_location_list,
        "User Number of Followers":user_followers_count_list,
        "Tweet Coordinates": tweet_coordinates_list,
        "Tweet Day and Time": tweet_date_time_list,
        "Tweet Number of Times Retweeted": tweet_num_retweet_list,
        "Tweet Number of Times Liked": tweet_num_liked_list,
        "Tweet Content": tweet_content_list})
# Out:
# Rate limit reached. Sleeping for: 724
# Rate limit reached. Sleeping for: 580
# Rate limit reached. Sleeping for: 634
# Rate limit reached. Sleeping for: 714
# Rate limit reached. Sleeping for: 712
# Rate limit reached. Sleeping for: 557
# Rate limit reached. Sleeping for: 634

# %%
df.shape
#df[0:3]
#df.to_csv('df_raw_data.csv')
# Out:
# (18158, 9)

# %% [markdown]
# <h3>Applying sentiment analysis to tweets</h3>

# %%
df = pd.read_csv('df_raw_data.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'Community Area Mentioned', 'Tweet Content',
#        'Tweet Coordinates', 'Tweet Day and Time',
#        'Tweet Number of Times Liked', 'Tweet Number of Times Retweeted',
#        'User Location', 'User Number of Followers', 'User Screen Name'],
#       dtype='object')

# %%
analyzer = SentimentIntensityAnalyzer()
df["Sentiment"] = df['Tweet Content'].apply(lambda tweet: analyzer.polarity_scores(tweet))

# %%
df[0:1]
# Out:
#    Unnamed: 0 Community Area Mentioned  \
# 0  0.0         rogers park
#
#                                                                                                                                   Tweet Content  \
# 0  RT @ChiTribBiz: This Rogers Park building is the latest to attract investor attention as the neighborhood undergoes “a renaissance” https:/…
#
#   Tweet Coordinates   Tweet Day and Time  Tweet Number of Times Liked  \
# 0  NaN               2016-12-13 18:48:38  0.0
#
#    Tweet Number of Times Retweeted User Location  User Number of Followers  \
# 0  2.0                              NaN           443.0
#
#   User Screen Name  \
# 0  giovannibacci36
#
#                                                       Sentiment
# 0  {'neu': 0.884, 'compound': 0.3612, 'pos': 0.116, 'neg': 0.0}

# %%
df.Sentiment[0]
#df['Sentiment'][0]

# The following examples demonstrate the value of the compound score:
# VADER is smart, handsome, and funny. {'neg': 0.0, 'neu': 0.254, 'pos': 0.746, 'compound': 0.8316} 
# VADER is smart, handsome, and funny! {'neg': 0.0, 'neu': 0.248, 'pos': 0.752, 'compound': 0.8439} 
# VADER is very smart, handsome, and funny. {'neg': 0.0, 'neu': 0.299, 'pos': 0.701, 'compound': 0.8545} 
# VADER is VERY SMART, handsome, and FUNNY. {'neg': 0.0, 'neu': 0.246, 'pos': 0.754, 'compound': 0.9227} 
# VADER is VERY SMART, handsome, and FUNNY!!! {'neg': 0.0, 'neu': 0.233, 'pos': 0.767, 'compound': 0.9342} 
# VADER is VERY SMART, really handsome, and INCREDIBLY FUNNY!!! {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.9469}
# Out:
# {'compound': 0.3612, 'neg': 0.0, 'neu': 0.884, 'pos': 0.116}

# %%
# prepare sentiment score for putting into a column of its own

# print(type(df['Sentiment'][0]))
type(df.Sentiment[0])
# Out:
# dict

# %%
# convert to string
#df['Sentiment'] = df['Sentiment'].apply(str)
df.Sentiment = df.Sentiment.apply(str)

type(df.Sentiment[0])
# Out:
# str

# %%
# now extract sentiment compound scores as additional column

df_temp = df.Sentiment.str.split(',').apply(pd.Series)
#df_temp[0:5]
df_temp[1][0:5]
# Out:
# 0     'compound': 0.3612
# 1     'compound': 0.3612
# 2     'compound': 0.34
# 3     'compound': 0.5574
# 4     'compound': 0.5574
# Name: 1, dtype: object

# %%
left_split = df_temp[1].str.split(': ').apply(pd.Series)
#left_split[1][0:5]
compound = left_split[1].apply(float)
df['Compound Sentiment Score'] = compound

# %%
#df[0:5]
df.to_csv('df_wCompound.csv')

# %% [markdown]
# <h3>Generating neighborhood reputation index scores for each neighborhood</h3>

# %%
df = pd.read_csv('df_wCompound.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Community Area Mentioned',
#        'Tweet Content', 'Tweet Coordinates', 'Tweet Day and Time',
#        'Tweet Number of Times Liked', 'Tweet Number of Times Retweeted',
#        'User Location', 'User Number of Followers', 'User Screen Name',
#        'Sentiment', 'Compound Sentiment Score'],
#       dtype='object')

# %%
del df['Unnamed: 0']
del df['Unnamed: 0.1']
df['Count 1'] = 1
df.shape
# Out:
# (18159, 12)

# %%
#df[0:5]

# %% [markdown]
# I assume that reputation entails both a sentiment (positive, negative) and its diffusion. Therefore I will compute a neighborhood reputation index using the sentiment data, as well as information on the number of "likes" and "retweets" for each tweet and followers for the author of each tweet.

# %%
# I begin by computing the diffusion of each tweet.
# I assume that likers, retweeters, and followers do not overlap although in reality they likely do.

# diffusion to passive readers (Followers)
df['User to Follower Diffusion'] = df['Compound Sentiment Score']*df['User Number of Followers']

# diffusion to more active readers, demonstrated by liking a tweet
df['User to Liker Diffusion'] = df['Compound Sentiment Score']*df['Tweet Number of Times Liked']

# diffusion to even more active readers, demonstrated by retweeting a tweet
df['User to Retweeter Diffusion'] = df['Compound Sentiment Score']*df['Tweet Number of Times Retweeted']

# total diffusion
df['Tweet Total Diffusion'] = df['User to Follower Diffusion'] + df['User to Liker Diffusion'] + df['User to Retweeter Diffusion']

# %%
# Now I establish the number of positive vs. negative sentiment tweets per neighborhood. 

tweet_by_neighb = df.groupby('Community Area Mentioned')

# total number of positive tweets per neighborhood:
total_tweet_by_neighb_pos_num = tweet_by_neighb.apply(lambda x: x[x['Compound Sentiment Score'] > 0]['Count 1'].sum())
# total number of negative tweets per neighborhood:
total_tweet_by_neighb_neg_num = tweet_by_neighb.apply(lambda x: x[x['Compound Sentiment Score'] < 0]['Count 1'].sum())
# total number of positive and negative tweets per neighborhood:
total_tweet_by_neighb_num = total_tweet_by_neighb_pos_num + total_tweet_by_neighb_neg_num

# %%
# Now I compute summary measures of the sentiment component of a neighborhood's reputation.
# Because I assume that a reputation involves a positive or negative sentiment, 
# I exclude all tweets that score as neutral (compound score = 0, review usign df[df['Compound Sentiment Score'] == 0]).

tweet_by_neighb = df.groupby('Community Area Mentioned')

for neighborhood in tweet_by_neighb:
    sum_pos_tweet_by_neighb = tweet_by_neighb.apply(lambda x: x[x['Compound Sentiment Score'] > 0]['Compound Sentiment Score'].sum())
    sum_neg_tweet_by_neighb = tweet_by_neighb.apply(lambda x: x[x['Compound Sentiment Score'] < 0]['Compound Sentiment Score'].sum())

# %%
neighb_level_df = pd.DataFrame({'Total Number of Positive Tweets':total_tweet_by_neighb_pos_num,
                                'Total Number of Negative Tweets':total_tweet_by_neighb_neg_num,
                                'Total Number of Positive and Negative Tweets': total_tweet_by_neighb_num,
                                'Sum Positive Tweet Sentiment':sum_pos_tweet_by_neighb,
                                'Sum Negative Tweet Sentiment':sum_neg_tweet_by_neighb})

# %%
neighb_level_df = neighb_level_df.drop(neighb_level_df.index[[0]])  # removes one row with no community area name

# %%
neighb_level_df
# Out:
#                           Sum Negative Tweet Sentiment  \
# Community Area Mentioned
# albany park              -5.6676
# archer heights            0.0000
# ashburn                  -10.6303
# auburn gresham           -5.9133
# austin                   -14.1287
# avalon park               0.0000
# avondale                 -7.2062
# belmont cragin            0.0000
# beverly                  -35.3824
# bridgeport               -16.1919
# brighton park            -0.5216
# burnside                 -3.4787
# chatham                  -72.7402
# chicago lawn             -7.2072
# clearing                 -33.5426
# douglas                  -44.9209
# dunning                  -8.8078
# east garfield park       -159.6528
# east side                -9.8968
# edgewater                -15.7117
# edison park              -0.5958
# englewood                -178.2184
# forest glen              -0.5574
# fuller park               0.0000
# gage park                -0.3818
# garfield ridge           -25.9085
# grand boulevard           0.0000
# greater grand crossing    0.0000
# hegewisch                 0.0000
# hermosa                  -10.6583
# ...                          ...
# montclaire                0.0000
# morgan park              -36.5963
# mount greenwood          -15.6672
# near north side          -0.8020
# near south side           0.0000
# near west side           -4.9914
# new city                 -68.2218
# north center             -10.4607
# north lawndale           -54.1112
# north park               -14.5291
# norwood park             -7.7546
# o'hare                   -0.4466
# oakland                  -18.7194
# portage park             -10.4311
# pullman                  -6.3766
# riverdale                -134.1097
# rogers park              -8.3172
# roseland                 -162.5234
# south chicago            -144.9457
# south deering             0.0000
# south shore              -26.3318
# uptown                   -57.6967
# washington park           0.0000
# west englewood           -18.0989
# west garfield park       -5.0693
# west lawn                -1.6820
# west pullman             -4.0916
# west ridge               -4.8305
# west town                -2.3882
# woodlawn                 -3.2651
#
#                           Sum Positive Tweet Sentiment  \
# Community Area Mentioned
# albany park               9.7646
# archer heights            0.5574
# ashburn                   5.5188
# auburn gresham            1.1233
# austin                    18.5554
# avalon park               0.0000
# avondale                  7.6270
# belmont cragin            0.0000
# beverly                   174.6288
# bridgeport                44.0589
# brighton park             2.0169
# burnside                  1.1148
# chatham                   14.6224
# chicago lawn              5.9058
# clearing                  61.5269
# douglas                   152.1378
# dunning                   22.1743
# east garfield park        5.5437
# east side                 23.0107
# edgewater                 37.0392
# edison park               8.7805
# englewood                 119.3052
# forest glen               0.9058
# fuller park               0.0000
# gage park                 2.5715
# garfield ridge            2.9174
# grand boulevard           4.7700
# greater grand crossing    8.1600
# hegewisch                 0.5106
# hermosa                   24.3991
# ...                          ...
# montclaire                0.0000
# morgan park               108.6903
# mount greenwood           6.5758
# near north side           7.8572
# near south side           3.9044
# near west side            12.8581
# new city                  106.1651
# north center              18.5448
# north lawndale            57.0527
# north park                38.2856
# norwood park              4.1417
# o'hare                    2.5444
# oakland                   6.1594
# portage park              15.3506
# pullman                   9.2418
# riverdale                 8.7716
# rogers park               92.8450
# roseland                  12.9962
# south chicago             132.6081
# south deering             0.5848
# south shore               38.3309
# uptown                    95.4810
# washington park           0.5994
# west englewood            1.0187
# west garfield park        4.6487
# west lawn                 1.2250
# west pullman              3.1795
# west ridge                14.4780
# west town                 25.6804
# woodlawn                  26.1762
#
#                           Total Number of Negative Tweets  \
# Community Area Mentioned
# albany park               16
# archer heights            0
# ashburn                   28
# auburn gresham            17
# austin                    34
# avalon park               0
# avondale                  18
# belmont cragin            0
# beverly                   115
# bridgeport                36
# brighton park             1
# burnside                  5
# chatham                   114
# chicago lawn              12
# clearing                  65
# douglas                   87
# dunning                   21
# east garfield park        287
# east side                 24
# edgewater                 42
# edison park               2
# englewood                 362
# forest glen               1
# fuller park               0
# gage park                 1
# garfield ridge            40
# grand boulevard           0
# greater grand crossing    0
# hegewisch                 0
# hermosa                   22
# ...                      ..
# montclaire                0
# morgan park               103
# mount greenwood           25
# near north side           1
# near south side           0
# near west side            19
# new city                  120
# north center              21
# north lawndale            112
# north park                36
# norwood park              21
# o'hare                    1
# oakland                   32
# portage park              19
# pullman                   14
# riverdale                 210
# rogers park               25
# roseland                  315
# south chicago             283
# south deering             0
# south shore               68
# uptown                    147
# washington park           0
# west englewood            32
# west garfield park        7
# west lawn                 6
# west pullman              10
# west ridge                7
# west town                 4
# woodlawn                  10
#
#                           Total Number of Positive Tweets  \
# Community Area Mentioned
# albany park               18
# archer heights            1
# ashburn                   15
# auburn gresham            2
# austin                    36
# avalon park               0
# avondale                  15
# belmont cragin            0
# beverly                   344
# bridgeport                87
# brighton park             3
# burnside                  2
# chatham                   27
# chicago lawn              19
# clearing                  131
# douglas                   264
# dunning                   65
# east garfield park        11
# east side                 45
# edgewater                 74
# edison park               17
# englewood                 238
# forest glen               1
# fuller park               0
# gage park                 4
# garfield ridge            5
# grand boulevard           10
# greater grand crossing    12
# hegewisch                 1
# hermosa                   58
# ...                      ..
# montclaire                0
# morgan park               200
# mount greenwood           14
# near north side           16
# near south side           8
# near west side            29
# new city                  224
# north center              40
# north lawndale            101
# north park                74
# norwood park              7
# o'hare                    5
# oakland                   22
# portage park              25
# pullman                   17
# riverdale                 20
# rogers park               168
# roseland                  30
# south chicago             266
# south deering             1
# south shore               86
# uptown                    236
# washington park           1
# west englewood            2
# west garfield park        8
# west lawn                 4
# west pullman              6
# west ridge                24
# west town                 50
# woodlawn                  47
#
#                           Total Number of Positive and Negative Tweets
# Community Area Mentioned
# albany park               34
# archer heights            1
# ashburn                   43
# auburn gresham            19
# austin                    70
# avalon park               0
# avondale                  33
# belmont cragin            0
# beverly                   459
# bridgeport                123
# brighton park             4
# burnside                  7
# chatham                   141
# chicago lawn              31
# clearing                  196
# douglas                   351
# dunning                   86
# east garfield park        298
# east side                 69
# edgewater                 116
# edison park               19
# englewood                 600
# forest glen               2
# fuller park               0
# gage park                 5
# garfield ridge            45
# grand boulevard           10
# greater grand crossing    12
# hegewisch                 1
# hermosa                   80
# ...                      ..
# montclaire                0
# morgan park               303
# mount greenwood           39
# near north side           17
# near south side           8
# near west side            48
# new city                  344
# north center              61
# north lawndale            213
# north park                110
# norwood park              28
# o'hare                    6
# oakland                   54
# portage park              44
# pullman                   31
# riverdale                 230
# rogers park               193
# roseland                  345
# south chicago             549
# south deering             1
# south shore               154
# uptown                    383
# washington park           1
# west englewood            34
# west garfield park        15
# west lawn                 10
# west pullman              16
# west ridge                31
# west town                 54
# woodlawn                  57
#
# [72 rows x 5 columns]

# %% [markdown]
# <h4>Computing weighted and evenly weighed reputation scores per neighborhood</h4>
#
# <u>Evenly Weighed Reputation Score:</u> Average is computed evenly, assuming a positive tweet is equal in influence as a negative tweet (except for direction of opinion)
#
# <u>Weighted Reputation Score:</u> Humans have a famous bias for the negative - "even when of equal intensity, things of a more negative nature (e.g. unpleasant thoughts, emotions, or social interactions; harmful/traumatic events) have a greater effect on one's psychological state and processes than do neutral or positive things" (https://en.wikipedia.org/wiki/Negativity_bias).
#
# To model this negativity bias, I consider a ratio from an HBR article (Folkman, Jack Zenger and Joseph. 2013. “The Ideal Praise-to-Criticism Ratio.” Harvard Business Review. March 15. https://hbr.org/2013/03/the-ideal-praise-to-criticism.), which suggests that the ideal praise-to-criticism ratio in the context of team performance assessments is as follows: 5 positive comments for every negative one. Based on this idea, the weighted reputation score calculation below pretends that there are five times as many negative tweets for every neighborhood.

# %%
for neighborhood in neighb_level_df:
    avg_neg = sum_neg_tweet_by_neighb / total_tweet_by_neighb_neg_num
    avg_pos = sum_pos_tweet_by_neighb / total_tweet_by_neighb_pos_num
    reputation_index_1 = (avg_neg+avg_pos) / 2
    reputation_index_2 = ((5*avg_neg)+avg_pos) / 6
    
neighb_level_df['Average Negative Sentiment'] = avg_neg
neighb_level_df['Average Positive Sentiment'] = avg_pos
neighb_level_df['Unweighted Reputation Score'] = reputation_index_1
neighb_level_df['Weighted Reputation Score'] = reputation_index_2

# %%
neighb_level_df.fillna(0, inplace=True)
neighb_level_df.sort_values(by='Unweighted Reputation Score')
# Out:
#                           Sum Negative Tweet Sentiment  \
# Community Area Mentioned
# near north side          -0.8020
# oakland                  -18.7194
# chicago lawn             -7.2072
# riverdale                -134.1097
# mount greenwood          -15.6672
# west garfield park       -5.0693
# burnside                 -3.4787
# hyde park                -79.1596
# chatham                  -72.7402
# new city                 -68.2218
# west ridge               -4.8305
# west town                -2.3882
# roseland                 -162.5234
# dunning                  -8.8078
# garfield ridge           -25.9085
# hermosa                  -10.6583
# west englewood           -18.0989
# east garfield park       -159.6528
# clearing                 -33.5426
# north center             -10.4607
# south chicago            -144.9457
# ashburn                  -10.6303
# montclaire                0.0000
# avalon park               0.0000
# washington park           0.0000
# hegewisch                 0.0000
# greater grand crossing    0.0000
# near south side           0.0000
# fuller park               0.0000
# south deering             0.0000
# ...                          ...
# south shore              -26.3318
# douglas                  -44.9209
# o'hare                   -0.4466
# portage park             -10.4311
# north lawndale           -54.1112
# pullman                  -6.3766
# east side                -9.8968
# austin                   -14.1287
# loop                     -155.8448
# avondale                 -7.2062
# irving park              -8.3567
# north park               -14.5291
# west pullman             -4.0916
# edgewater                -15.7117
# lake view                -6.6750
# brighton park            -0.5216
# near west side           -4.9914
# morgan park              -36.5963
# albany park              -5.6676
# beverly                  -35.3824
# lower west side          -0.2960
# auburn gresham           -5.9133
# edison park              -0.5958
# rogers park              -8.3172
# norwood park             -7.7546
# lincoln square           -2.3563
# woodlawn                 -3.2651
# gage park                -0.3818
# humboldt park            -27.2708
# forest glen              -0.5574
#
#                           Sum Positive Tweet Sentiment  \
# Community Area Mentioned
# near north side           7.8572
# oakland                   6.1594
# chicago lawn              5.9058
# riverdale                 8.7716
# mount greenwood           6.5758
# west garfield park        4.6487
# burnside                  1.1148
# hyde park                 124.0035
# chatham                   14.6224
# new city                  106.1651
# west ridge                14.4780
# west town                 25.6804
# roseland                  12.9962
# dunning                   22.1743
# garfield ridge            2.9174
# hermosa                   24.3991
# west englewood            1.0187
# east garfield park        5.5437
# clearing                  61.5269
# north center              18.5448
# south chicago             132.6081
# ashburn                   5.5188
# montclaire                0.0000
# avalon park               0.0000
# washington park           0.5994
# hegewisch                 0.5106
# greater grand crossing    8.1600
# near south side           3.9044
# fuller park               0.0000
# south deering             0.5848
# ...                          ...
# south shore               38.3309
# douglas                   152.1378
# o'hare                    2.5444
# portage park              15.3506
# north lawndale            57.0527
# pullman                   9.2418
# east side                 23.0107
# austin                    18.5554
# loop                      330.7517
# avondale                  7.6270
# irving park               9.9079
# north park                38.2856
# west pullman              3.1795
# edgewater                 37.0392
# lake view                 16.2563
# brighton park             2.0169
# near west side            12.8581
# morgan park               108.6903
# albany park               9.7646
# beverly                   174.6288
# lower west side           0.5093
# auburn gresham            1.1233
# edison park               8.7805
# rogers park               92.8450
# norwood park              4.1417
# lincoln square            88.3560
# woodlawn                  26.1762
# gage park                 2.5715
# humboldt park             22.3413
# forest glen               0.9058
#
#                           Total Number of Negative Tweets  \
# Community Area Mentioned
# near north side           1
# oakland                   32
# chicago lawn              12
# riverdale                 210
# mount greenwood           25
# west garfield park        7
# burnside                  5
# hyde park                 122
# chatham                   114
# new city                  120
# west ridge                7
# west town                 4
# roseland                  315
# dunning                   21
# garfield ridge            40
# hermosa                   22
# west englewood            32
# east garfield park        287
# clearing                  65
# north center              21
# south chicago             283
# ashburn                   28
# montclaire                0
# avalon park               0
# washington park           0
# hegewisch                 0
# greater grand crossing    0
# near south side           0
# fuller park               0
# south deering             0
# ...                      ..
# south shore               68
# douglas                   87
# o'hare                    1
# portage park              19
# north lawndale            112
# pullman                   14
# east side                 24
# austin                    34
# loop                      407
# avondale                  18
# irving park               23
# north park                36
# west pullman              10
# edgewater                 42
# lake view                 15
# brighton park             1
# near west side            19
# morgan park               103
# albany park               16
# beverly                   115
# lower west side           1
# auburn gresham            17
# edison park               2
# rogers park               25
# norwood park              21
# lincoln square            7
# woodlawn                  10
# gage park                 1
# humboldt park             126
# forest glen               1
#
#                           Total Number of Positive Tweets  \
# Community Area Mentioned
# near north side           16
# oakland                   22
# chicago lawn              19
# riverdale                 20
# mount greenwood           14
# west garfield park        8
# burnside                  2
# hyde park                 239
# chatham                   27
# new city                  224
# west ridge                24
# west town                 50
# roseland                  30
# dunning                   65
# garfield ridge            5
# hermosa                   58
# west englewood            2
# east garfield park        11
# clearing                  131
# north center              40
# south chicago             266
# ashburn                   15
# montclaire                0
# avalon park               0
# washington park           1
# hegewisch                 1
# greater grand crossing    12
# near south side           8
# fuller park               0
# south deering             1
# ...                      ..
# south shore               86
# douglas                   264
# o'hare                    5
# portage park              25
# north lawndale            101
# pullman                   17
# east side                 45
# austin                    36
# loop                      677
# avondale                  15
# irving park               21
# north park                74
# west pullman              6
# edgewater                 74
# lake view                 28
# brighton park             3
# near west side            29
# morgan park               200
# albany park               18
# beverly                   344
# lower west side           1
# auburn gresham            2
# edison park               17
# rogers park               168
# norwood park              7
# lincoln square            157
# woodlawn                  47
# gage park                 4
# humboldt park             45
# forest glen               1
#
#                           Total Number of Positive and Negative Tweets  \
# Community Area Mentioned
# near north side           17
# oakland                   54
# chicago lawn              31
# riverdale                 230
# mount greenwood           39
# west garfield park        15
# burnside                  7
# hyde park                 361
# chatham                   141
# new city                  344
# west ridge                31
# west town                 54
# roseland                  345
# dunning                   86
# garfield ridge            45
# hermosa                   80
# west englewood            34
# east garfield park        298
# clearing                  196
# north center              61
# south chicago             549
# ashburn                   43
# montclaire                0
# avalon park               0
# washington park           1
# hegewisch                 1
# greater grand crossing    12
# near south side           8
# fuller park               0
# south deering             1
# ...                      ..
# south shore               154
# douglas                   351
# o'hare                    6
# portage park              44
# north lawndale            213
# pullman                   31
# east side                 69
# austin                    70
# loop                      1084
# avondale                  33
# irving park               44
# north park                110
# west pullman              16
# edgewater                 116
# lake view                 43
# brighton park             4
# near west side            48
# morgan park               303
# albany park               34
# beverly                   459
# lower west side           2
# auburn gresham            19
# edison park               19
# rogers park               193
# norwood park              28
# lincoln square            164
# woodlawn                  57
# gage park                 5
# humboldt park             171
# forest glen               2
#
#                           Average Negative Sentiment  \
# Community Area Mentioned
# near north side          -0.802000
# oakland                  -0.584981
# chicago lawn             -0.600600
# riverdale                -0.638618
# mount greenwood          -0.626688
# west garfield park       -0.724186
# burnside                 -0.695740
# hyde park                -0.648849
# chatham                  -0.638072
# new city                 -0.568515
# west ridge               -0.690071
# west town                -0.597050
# roseland                 -0.515947
# dunning                  -0.419419
# garfield ridge           -0.647713
# hermosa                  -0.484468
# west englewood           -0.565591
# east garfield park       -0.556282
# clearing                 -0.516040
# north center             -0.498129
# south chicago            -0.512176
# ashburn                  -0.379654
# montclaire                0.000000
# avalon park               0.000000
# washington park           0.000000
# hegewisch                 0.000000
# greater grand crossing    0.000000
# near south side           0.000000
# fuller park               0.000000
# south deering             0.000000
# ...                            ...
# south shore              -0.387232
# douglas                  -0.516332
# o'hare                   -0.446600
# portage park             -0.549005
# north lawndale           -0.483136
# pullman                  -0.455471
# east side                -0.412367
# austin                   -0.415550
# loop                     -0.382911
# avondale                 -0.400344
# irving park              -0.363335
# north park               -0.403586
# west pullman             -0.409160
# edgewater                -0.374088
# lake view                -0.445000
# brighton park            -0.521600
# near west side           -0.262705
# morgan park              -0.355304
# albany park              -0.354225
# beverly                  -0.307673
# lower west side          -0.296000
# auburn gresham           -0.347841
# edison park              -0.297900
# rogers park              -0.332688
# norwood park             -0.369267
# lincoln square           -0.336614
# woodlawn                 -0.326510
# gage park                -0.381800
# humboldt park            -0.216435
# forest glen              -0.557400
#
#                           Average Positive Sentiment  \
# Community Area Mentioned
# near north side           0.491075
# oakland                   0.279973
# chicago lawn              0.310832
# riverdale                 0.438580
# mount greenwood           0.469700
# west garfield park        0.581088
# burnside                  0.557400
# hyde park                 0.518843
# chatham                   0.541570
# new city                  0.473951
# west ridge                0.603250
# west town                 0.513608
# roseland                  0.433207
# dunning                   0.341143
# garfield ridge            0.583480
# hermosa                   0.420674
# west englewood            0.509350
# east garfield park        0.503973
# clearing                  0.469671
# north center              0.463620
# south chicago             0.498527
# ashburn                   0.367920
# montclaire                0.000000
# avalon park               0.000000
# washington park           0.599400
# hegewisch                 0.510600
# greater grand crossing    0.680000
# near south side           0.488050
# fuller park               0.000000
# south deering             0.584800
# ...                            ...
# south shore               0.445708
# douglas                   0.576280
# o'hare                    0.508880
# portage park              0.614024
# north lawndale            0.564878
# pullman                   0.543635
# east side                 0.511349
# austin                    0.515428
# loop                      0.488555
# avondale                  0.508467
# irving park               0.471805
# north park                0.517373
# west pullman              0.529917
# edgewater                 0.500530
# lake view                 0.580582
# brighton park             0.672300
# near west side            0.443383
# morgan park               0.543451
# albany park               0.542478
# beverly                   0.507642
# lower west side           0.509300
# auburn gresham            0.561650
# edison park               0.516500
# rogers park               0.552649
# norwood park              0.591671
# lincoln square            0.562777
# woodlawn                  0.556940
# gage park                 0.642875
# humboldt park             0.496473
# forest glen               0.905800
#
#                           Unweighted Reputation Score  \
# Community Area Mentioned
# near north side          -0.155463
# oakland                  -0.152504
# chicago lawn             -0.144884
# riverdale                -0.100019
# mount greenwood          -0.078494
# west garfield park       -0.071549
# burnside                 -0.069170
# hyde park                -0.065003
# chatham                  -0.048251
# new city                 -0.047282
# west ridge               -0.043411
# west town                -0.041721
# roseland                 -0.041370
# dunning                  -0.039138
# garfield ridge           -0.032116
# hermosa                  -0.031897
# west englewood           -0.028120
# east garfield park       -0.026154
# clearing                 -0.023185
# north center             -0.017254
# south chicago            -0.006824
# ashburn                  -0.005867
# montclaire                0.000000
# avalon park               0.000000
# washington park           0.000000
# hegewisch                 0.000000
# greater grand crossing    0.000000
# near south side           0.000000
# fuller park               0.000000
# south deering             0.000000
# ...                            ...
# south shore               0.029238
# douglas                   0.029974
# o'hare                    0.031140
# portage park              0.032509
# north lawndale            0.040871
# pullman                   0.044082
# east side                 0.049491
# austin                    0.049939
# loop                      0.052822
# avondale                  0.054061
# irving park               0.054235
# north park                0.056893
# west pullman              0.060378
# edgewater                 0.063221
# lake view                 0.067791
# brighton park             0.075350
# near west side            0.090339
# morgan park               0.094074
# albany park               0.094126
# beverly                   0.099984
# lower west side           0.106650
# auburn gresham            0.106904
# edison park               0.109300
# rogers park               0.109980
# norwood park              0.111202
# lincoln square            0.113081
# woodlawn                  0.115215
# gage park                 0.130538
# humboldt park             0.140019
# forest glen               0.174200
#
#                           Weighted Reputation Score
# Community Area Mentioned
# near north side          -0.586487
# oakland                  -0.440822
# chicago lawn             -0.448695
# riverdale                -0.459085
# mount greenwood          -0.443957
# west garfield park       -0.506640
# burnside                 -0.486883
# hyde park                -0.454234
# chatham                  -0.441465
# new city                 -0.394771
# west ridge               -0.474518
# west town                -0.411940
# roseland                 -0.357755
# dunning                  -0.292659
# garfield ridge           -0.442514
# hermosa                  -0.333611
# west englewood           -0.386434
# east garfield park       -0.379572
# clearing                 -0.351755
# north center             -0.337837
# south chicago            -0.343725
# ashburn                  -0.255058
# montclaire                0.000000
# avalon park               0.000000
# washington park           0.000000
# hegewisch                 0.000000
# greater grand crossing    0.000000
# near south side           0.000000
# fuller park               0.000000
# south deering             0.000000
# ...                            ...
# south shore              -0.248409
# douglas                  -0.334230
# o'hare                   -0.287353
# portage park             -0.355167
# north lawndale           -0.308467
# pullman                  -0.288954
# east side                -0.258414
# austin                   -0.260387
# loop                     -0.237667
# avondale                 -0.248876
# irving park              -0.224145
# north park               -0.250093
# west pullman             -0.252647
# edgewater                -0.228318
# lake view                -0.274070
# brighton park            -0.322617
# near west side           -0.145024
# morgan park              -0.205511
# albany park              -0.204775
# beverly                  -0.171787
# lower west side          -0.161783
# auburn gresham           -0.196259
# edison park              -0.162167
# rogers park              -0.185132
# norwood park             -0.209110
# lincoln square           -0.186716
# woodlawn                 -0.179268
# gage park                -0.211021
# humboldt park            -0.097617
# forest glen              -0.313533
#
# [72 rows x 9 columns]

# %%
neighb_level_df.shape
neighb_level_df.to_csv('df_neighb_level.csv')

# %% [markdown]
# <h3>Putting socioeconomic and Twitter data per neighborhood into one table</h3>

# %%
df_neighb_level = pd.read_csv('df_neighb_level.csv')
df_SES = pd.read_csv('Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv')
df_SES = df_SES.dropna()  # do this so that the last row is dropped, which totals for the whole city

# %%
print(df_neighb_level.shape)
print(df_SES.shape)
# neighborhood level df appears to be missing some community areas, assume that it's bc these were not mentioned in tweets
# Out:
# (72, 10)
# (77, 9)

# %%
# prepare for merging the two dataframes on df_SES['COMMUNITY AREA NAME'] and df_neighb_level['Community Area Mentioned']
df_SES = df_SES.sort_values(by='COMMUNITY AREA NAME')  # assure both columns are sorted in same direction
df_SES['COMMUNITY AREA NAME'] = df_SES['COMMUNITY AREA NAME'].apply(lambda x: x.lower())  # assure both are in lowercase
df_neighb_level.columns.values[0] ='COMMUNITY AREA NAME'  # assure both columns are named the same

# %%
print(df_neighb_level.columns)
print(df_SES.columns)
# Out:
# Index(['COMMUNITY AREA NAME', 'Sum Negative Tweet Sentiment',
#        'Sum Positive Tweet Sentiment', 'Total Number of Negative Tweets',
#        'Total Number of Positive Tweets',
#        'Total Number of Positive and Negative Tweets',
#        'Average Negative Sentiment', 'Average Positive Sentiment',
#        'Unweighted Reputation Score', 'Weighted Reputation Score'],
#       dtype='object')
# Index(['Community Area Number', 'COMMUNITY AREA NAME',
#        'PERCENT OF HOUSING CROWDED', 'PERCENT HOUSEHOLDS BELOW POVERTY',
#        'PERCENT AGED 16+ UNEMPLOYED',
#        'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
#        'PERCENT AGED UNDER 18 OR OVER 64', 'PER CAPITA INCOME ',
#        'HARDSHIP INDEX'],
#       dtype='object')

# %%
df_merged = df_SES.merge(df_neighb_level, 
                         how='left', 
                         on='COMMUNITY AREA NAME')
df_merged = df_merged.sort_values(by='Community Area Number')
df_merged = df_merged.fillna('NA')
df_merged
# Out:
#     Community Area Number     COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 60  1.0                    rogers park             7.7
# 74  2.0                    west ridge              7.8
# 66  3.0                    uptown                  3.8
# 39  4.0                    lincoln square          3.4
# 51  5.0                    north center            0.3
# 37  6.0                    lake view               1.1
# 38  7.0                    lincoln park            0.8
# 47  8.0                    near north side         1.9
# 22  9.0                    edison park             1.1
# 54  10.0                   norwood park            2.0
# 35  11.0                   jefferson park          2.7
# 24  12.0                   forest glen             1.1
# 53  13.0                   north park              3.9
# 0   14.0                   albany park             11.3
# 57  15.0                   portage park            4.1
# 34  16.0                   irving park             6.3
# 18  17.0                   dunning                 5.2
# 44  18.0                   montclaire              8.1
# 8   19.0                   belmont cragin          10.8
# 31  20.0                   hermosa                 6.9
# 7   21.0                   avondale                6.0
# 40  22.0                   logan square            3.2
# 32  23.0                   humboldt park           14.8
# 75  24.0                   west town               2.3
# 5   25.0                   austin                  6.3
# 71  26.0                   west garfield park      9.4
# 19  27.0                   east garfield park      8.2
# 49  28.0                   near west side          3.8
# 52  29.0                   north lawndale          7.4
# 64  30.0                   south lawndale          15.2
# ..   ...                              ...           ...
# 13  48.0                   calumet heights         2.1
# 61  49.0                   roseland                2.5
# 58  50.0                   pullman                 1.5
# 63  51.0                   south deering           4.0
# 20  52.0                   east side               6.8
# 73  53.0                   west pullman            3.3
# 59  54.0                   riverdale               5.8
# 30  55.0                   hegewisch               3.3
# 27  56.0                   garfield ridge          2.6
# 1   57.0                   archer heights          8.5
# 11  58.0                   brighton park           14.4
# 43  59.0                   mckinley park           7.2
# 10  60.0                   bridgeport              4.5
# 50  61.0                   new city                11.9
# 69  62.0                   west elsdon             11.1
# 26  63.0                   gage park               15.8
# 16  64.0                   clearing                2.7
# 72  65.0                   west lawn               5.8
# 15  66.0                   chicago lawn            7.6
# 70  67.0                   west englewood          4.8
# 23  68.0                   englewood               3.8
# 29  69.0                   greater grand crossing  3.6
# 3   70.0                   ashburn                 4.0
# 4   71.0                   auburn gresham          4.0
# 9   72.0                   beverly                 0.9
# 67  73.0                   washington height       1.1
# 46  74.0                   mount greenwood         1.0
# 45  75.0                   morgan park             0.8
# 55  76.0                   o'hare                  3.6
# 21  77.0                   edgewater               4.1
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 60  23.6                              8.7
# 74  17.2                              8.8
# 66  24.0                              8.9
# 39  10.9                              8.2
# 51  7.5                               5.2
# 37  11.4                              4.7
# 38  12.3                              5.1
# 47  12.9                              7.0
# 22  3.3                               6.5
# 54  5.4                               9.0
# 35  8.6                               12.4
# 24  7.5                               6.8
# 53  13.2                              9.9
# 0   19.2                              10.0
# 57  11.6                              12.6
# 34  13.1                              10.0
# 18  10.6                              10.0
# 44  15.3                              13.8
# 8   18.7                              14.6
# 31  20.5                              13.1
# 7   15.3                              9.2
# 40  16.8                              8.2
# 32  33.9                              17.3
# 75  14.7                              6.6
# 5   28.6                              22.6
# 71  41.7                              25.8
# 19  42.4                              19.6
# 49  20.6                              10.7
# 52  43.1                              21.2
# 64  30.7                              15.8
# ..   ...                               ...
# 13  11.5                              20.0
# 61  19.8                              20.3
# 58  21.6                              22.8
# 63  29.2                              16.3
# 20  19.2                              12.1
# 73  25.9                              19.4
# 59  56.5                              34.6
# 30  17.1                              9.6
# 27  8.8                               11.3
# 1   14.1                              16.5
# 11  23.6                              13.9
# 43  18.7                              13.4
# 10  18.9                              13.7
# 50  29.0                              23.0
# 69  15.6                              16.7
# 26  23.4                              18.2
# 16  8.9                               9.5
# 72  14.9                              9.6
# 15  27.9                              17.1
# 70  34.4                              35.9
# 23  46.6                              28.0
# 29  29.6                              23.0
# 3   10.4                              11.7
# 4   27.6                              28.3
# 9   5.1                               8.0
# 67  16.9                              20.8
# 46  3.4                               8.7
# 45  13.2                              15.0
# 55  15.4                              7.1
# 21  18.2                              9.2
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 60  18.2
# 74  20.8
# 66  11.8
# 39  13.4
# 51  4.5
# 37  2.6
# 38  3.6
# 47  2.5
# 22  7.4
# 54  11.5
# 35  13.4
# 24  4.9
# 53  14.4
# 0   32.9
# 57  19.3
# 34  22.4
# 18  16.2
# 44  23.5
# 8   37.3
# 31  41.6
# 7   24.7
# 40  14.8
# 32  35.4
# 75  12.9
# 5   24.4
# 71  24.5
# 19  21.3
# 49  9.6
# 52  27.6
# 64  54.8
# ..   ...
# 13  11.0
# 61  16.9
# 58  13.1
# 63  21.0
# 20  31.9
# 73  20.5
# 59  27.5
# 30  19.2
# 27  19.3
# 1   35.9
# 11  45.1
# 43  32.9
# 10  22.2
# 50  41.5
# 69  37.0
# 26  51.5
# 16  18.8
# 72  33.6
# 15  31.2
# 70  26.3
# 23  28.5
# 29  16.5
# 3   17.7
# 4   18.5
# 9   3.7
# 67  13.7
# 46  4.3
# 45  10.8
# 55  10.9
# 21  9.7
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX  \
# 60  27.5                              23939               39.0
# 74  38.5                              23040               46.0
# 66  22.2                              35787               20.0
# 39  25.5                              37524               17.0
# 51  26.2                              57123               6.0
# 37  17.0                              60058               5.0
# 38  21.5                              71551               2.0
# 47  22.6                              88669               1.0
# 22  35.3                              40959               8.0
# 54  39.5                              32875               21.0
# 35  35.5                              27751               25.0
# 24  40.5                              44164               11.0
# 53  39.0                              26576               33.0
# 0   32.0                              21323               53.0
# 57  34.0                              24336               35.0
# 34  31.6                              27249               34.0
# 18  33.6                              26282               28.0
# 44  38.6                              22014               50.0
# 8   37.3                              15461               70.0
# 31  36.4                              15089               71.0
# 7   31.0                              20039               42.0
# 40  26.2                              31908               23.0
# 32  38.0                              13781               85.0
# 75  21.7                              43198               10.0
# 5   37.9                              15957               73.0
# 71  43.6                              10934               92.0
# 19  43.2                              12961               83.0
# 49  22.2                              44689               15.0
# 52  42.7                              12034               87.0
# 64  33.8                              10402               96.0
# ..   ...                                ...                ...
# 13  44.0                              28887               38.0
# 61  41.2                              17949               52.0
# 58  38.6                              20588               51.0
# 63  39.5                              14685               65.0
# 20  42.8                              17104               64.0
# 73  42.1                              16563               62.0
# 59  51.5                              8201                98.0
# 30  42.9                              22677               44.0
# 27  38.1                              26353               32.0
# 1   39.2                              16134               67.0
# 11  39.3                              13089               84.0
# 43  35.6                              16954               61.0
# 10  31.3                              22694               43.0
# 50  38.9                              12765               91.0
# 69  37.7                              15754               69.0
# 26  38.8                              12171               93.0
# 16  37.6                              25113               29.0
# 72  39.6                              16907               56.0
# 15  40.6                              13231               80.0
# 70  40.7                              11317               89.0
# 23  42.5                              11888               94.0
# 29  41.0                              17285               66.0
# 3   36.9                              23482               37.0
# 4   41.9                              15528               74.0
# 9   40.5                              39523               12.0
# 67  42.6                              19713               48.0
# 46  36.8                              34381               16.0
# 45  40.3                              27149               30.0
# 55  30.3                              25828               24.0
# 21  23.8                              33385               19.0
#
#    Sum Negative Tweet Sentiment Sum Positive Tweet Sentiment  \
# 60 -8.3172                       92.845
# 74 -4.8305                       14.478
# 66 -57.6967                      95.481
# 39 -2.3563                       88.356
# 51 -10.4607                      18.5448
# 37 -6.675                        16.2563
# 38 -94.7576                      310.297
# 47 -0.802                        7.8572
# 22 -0.5958                       8.7805
# 54 -7.7546                       4.1417
# 35 -24.5815                      10.493
# 24 -0.5574                       0.9058
# 53 -14.5291                      38.2856
# 0  -5.6676                       9.7646
# 57 -10.4311                      15.3506
# 34 -8.3567                       9.9079
# 18 -8.8078                       22.1743
# 44  0                            0
# 8   0                            0
# 31 -10.6583                      24.3991
# 7  -7.2062                       7.627
# 40 -24.9594                      74.0059
# 32 -27.2708                      22.3413
# 75 -2.3882                       25.6804
# 5  -14.1287                      18.5554
# 71 -5.0693                       4.6487
# 19 -159.653                      5.5437
# 49 -4.9914                       12.8581
# 52 -54.1112                      57.0527
# 64  NA                           NA
# ..  ..                           ..
# 13  NA                           NA
# 61 -162.523                      12.9962
# 58 -6.3766                       9.2418
# 63  0                            0.5848
# 20 -9.8968                       23.0107
# 73 -4.0916                       3.1795
# 59 -134.11                       8.7716
# 30  0                            0.5106
# 27 -25.9085                      2.9174
# 1   0                            0.5574
# 11 -0.5216                       2.0169
# 43 -0.5053                       0.5106
# 10 -16.1919                      44.0589
# 50 -68.2218                      106.165
# 69  NA                           NA
# 26 -0.3818                       2.5715
# 16 -33.5426                      61.5269
# 72 -1.682                        1.225
# 15 -7.2072                       5.9058
# 70 -18.0989                      1.0187
# 23 -178.218                      119.305
# 29  0                            8.16
# 3  -10.6303                      5.5188
# 4  -5.9133                       1.1233
# 9  -35.3824                      174.629
# 67  NA                           NA
# 46 -15.6672                      6.5758
# 45 -36.5963                      108.69
# 55 -0.4466                       2.5444
# 21 -15.7117                      37.0392
#
#    Total Number of Negative Tweets Total Number of Positive Tweets  \
# 60  25                              168
# 74  7                               24
# 66  147                             236
# 39  7                               157
# 51  21                              40
# 37  15                              28
# 38  182                             582
# 47  1                               16
# 22  2                               17
# 54  21                              7
# 35  49                              20
# 24  1                               1
# 53  36                              74
# 0   16                              18
# 57  19                              25
# 34  23                              21
# 18  21                              65
# 44  0                               0
# 8   0                               0
# 31  22                              58
# 7   18                              15
# 40  60                              161
# 32  126                             45
# 75  4                               50
# 5   34                              36
# 71  7                               8
# 19  287                             11
# 49  19                              29
# 52  112                             101
# 64  NA                              NA
# ..  ..                              ..
# 13  NA                              NA
# 61  315                             30
# 58  14                              17
# 63  0                               1
# 20  24                              45
# 73  10                              6
# 59  210                             20
# 30  0                               1
# 27  40                              5
# 1   0                               1
# 11  1                               3
# 43  1                               1
# 10  36                              87
# 50  120                             224
# 69  NA                              NA
# 26  1                               4
# 16  65                              131
# 72  6                               4
# 15  12                              19
# 70  32                              2
# 23  362                             238
# 29  0                               12
# 3   28                              15
# 4   17                              2
# 9   115                             344
# 67  NA                              NA
# 46  25                              14
# 45  103                             200
# 55  1                               5
# 21  42                              74
#
#    Total Number of Positive and Negative Tweets Average Negative Sentiment  \
# 60  193                                         -0.332688
# 74  31                                          -0.690071
# 66  383                                         -0.392495
# 39  164                                         -0.336614
# 51  61                                          -0.498129
# 37  43                                          -0.445
# 38  764                                         -0.520646
# 47  17                                          -0.802
# 22  19                                          -0.2979
# 54  28                                          -0.369267
# 35  69                                          -0.501663
# 24  2                                           -0.5574
# 53  110                                         -0.403586
# 0   34                                          -0.354225
# 57  44                                          -0.549005
# 34  44                                          -0.363335
# 18  86                                          -0.419419
# 44  0                                            0
# 8   0                                            0
# 31  80                                          -0.484468
# 7   33                                          -0.400344
# 40  221                                         -0.41599
# 32  171                                         -0.216435
# 75  54                                          -0.59705
# 5   70                                          -0.41555
# 71  15                                          -0.724186
# 19  298                                         -0.556282
# 49  48                                          -0.262705
# 52  213                                         -0.483136
# 64  NA                                           NA
# ..  ..                                           ..
# 13  NA                                           NA
# 61  345                                         -0.515947
# 58  31                                          -0.455471
# 63  1                                            0
# 20  69                                          -0.412367
# 73  16                                          -0.40916
# 59  230                                         -0.638618
# 30  1                                            0
# 27  45                                          -0.647713
# 1   1                                            0
# 11  4                                           -0.5216
# 43  2                                           -0.5053
# 10  123                                         -0.449775
# 50  344                                         -0.568515
# 69  NA                                           NA
# 26  5                                           -0.3818
# 16  196                                         -0.51604
# 72  10                                          -0.280333
# 15  31                                          -0.6006
# 70  34                                          -0.565591
# 23  600                                         -0.492316
# 29  12                                           0
# 3   43                                          -0.379654
# 4   19                                          -0.347841
# 9   459                                         -0.307673
# 67  NA                                           NA
# 46  39                                          -0.626688
# 45  303                                         -0.355304
# 55  6                                           -0.4466
# 21  116                                         -0.374088
#
#    Average Positive Sentiment Unweighted Reputation Score  \
# 60  0.552649                   0.10998
# 74  0.60325                   -0.0434107
# 66  0.404581                   0.00604298
# 39  0.562777                   0.113081
# 51  0.46362                   -0.0172543
# 37  0.580582                   0.0677911
# 38  0.533156                   0.0062551
# 47  0.491075                  -0.155463
# 22  0.5165                     0.1093
# 54  0.591671                   0.111202
# 35  0.52465                    0.0114934
# 24  0.9058                     0.1742
# 53  0.517373                   0.0568934
# 0   0.542478                   0.0941264
# 57  0.614024                   0.0325094
# 34  0.471805                   0.054235
# 18  0.341143                  -0.039138
# 44  0                          0
# 8   0                          0
# 31  0.420674                  -0.031897
# 7   0.508467                   0.0540611
# 40  0.459664                   0.021837
# 32  0.496473                   0.140019
# 75  0.513608                  -0.041721
# 5   0.515428                   0.0499389
# 71  0.581088                  -0.0715491
# 19  0.503973                  -0.0261544
# 49  0.443383                   0.0903387
# 52  0.564878                   0.0408713
# 64  NA                         NA
# ..  ..                         ..
# 13  NA                         NA
# 61  0.433207                  -0.0413703
# 58  0.543635                   0.0440819
# 63  0.5848                     0
# 20  0.511349                   0.0494911
# 73  0.529917                   0.0603783
# 59  0.43858                   -0.100019
# 30  0.5106                     0
# 27  0.58348                   -0.0321163
# 1   0.5574                     0
# 11  0.6723                     0.07535
# 43  0.5106                     0.00265
# 10  0.506424                   0.0283246
# 50  0.473951                  -0.0472818
# 69  NA                         NA
# 26  0.642875                   0.130538
# 16  0.469671                  -0.0231845
# 72  0.30625                    0.0129583
# 15  0.310832                  -0.144884
# 70  0.50935                   -0.0281203
# 23  0.501282                   0.00448317
# 29  0.68                       0
# 3   0.36792                   -0.00586679
# 4   0.56165                    0.106904
# 9   0.507642                   0.0999844
# 67  NA                         NA
# 46  0.4697                    -0.078494
# 45  0.543451                   0.0940738
# 55  0.50888                    0.03114
# 21  0.50053                    0.0632208
#
#    Weighted Reputation Score
# 60 -0.185132
# 74 -0.474518
# 66 -0.259649
# 39 -0.186716
# 51 -0.337837
# 37 -0.27407
# 38 -0.345012
# 47 -0.586487
# 22 -0.162167
# 54 -0.20911
# 35 -0.330611
# 24 -0.313533
# 53 -0.250093
# 0  -0.204775
# 57 -0.355167
# 34 -0.224145
# 18 -0.292659
# 44  0
# 8   0
# 31 -0.333611
# 7  -0.248876
# 40 -0.270048
# 32 -0.0976169
# 75 -0.41194
# 5  -0.260387
# 71 -0.50664
# 19 -0.379572
# 49 -0.145024
# 52 -0.308467
# 64  NA
# ..  ..
# 13  NA
# 61 -0.357755
# 58 -0.288954
# 63  0
# 20 -0.258414
# 73 -0.252647
# 59 -0.459085
# 30  0
# 27 -0.442514
# 1   0
# 11 -0.322617
# 43 -0.335983
# 10 -0.290408
# 50 -0.394771
# 69  NA
# 26 -0.211021
# 16 -0.351755
# 72 -0.182569
# 15 -0.448695
# 70 -0.386434
# 23 -0.326716
# 29  0
# 3  -0.255058
# 4  -0.196259
# 9  -0.171787
# 67  NA
# 46 -0.443957
# 45 -0.205511
# 55 -0.287353
# 21 -0.228318
#
# [77 rows x 18 columns]

# %%
# show me the neighborhoods that are not mentioned even once among the tweets downloaded for this round of analysis
df_merged[df_merged['Unweighted Reputation Score'] == 'NA']
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 64  30.0                   south lawndale      15.2
# 2   34.0                   armour square       5.7
# 13  48.0                   calumet heights     2.1
# 69  62.0                   west elsdon         11.1
# 67  73.0                   washington height   1.1
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 64  30.7                              15.8
# 2   40.1                              16.7
# 13  11.5                              20.0
# 69  15.6                              16.7
# 67  16.9                              20.8
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 64  54.8
# 2   34.5
# 13  11.0
# 69  37.0
# 67  13.7
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX  \
# 64  33.8                              10402               96.0
# 2   38.3                              16148               82.0
# 13  44.0                              28887               38.0
# 69  37.7                              15754               69.0
# 67  42.6                              19713               48.0
#
#    Sum Negative Tweet Sentiment Sum Positive Tweet Sentiment  \
# 64  NA                           NA
# 2   NA                           NA
# 13  NA                           NA
# 69  NA                           NA
# 67  NA                           NA
#
#    Total Number of Negative Tweets Total Number of Positive Tweets  \
# 64  NA                              NA
# 2   NA                              NA
# 13  NA                              NA
# 69  NA                              NA
# 67  NA                              NA
#
#    Total Number of Positive and Negative Tweets Average Negative Sentiment  \
# 64  NA                                           NA
# 2   NA                                           NA
# 13  NA                                           NA
# 69  NA                                           NA
# 67  NA                                           NA
#
#    Average Positive Sentiment Unweighted Reputation Score  \
# 64  NA                         NA
# 2   NA                         NA
# 13  NA                         NA
# 69  NA                         NA
# 67  NA                         NA
#
#    Weighted Reputation Score
# 64  NA
# 2   NA
# 13  NA
# 69  NA
# 67  NA

# %%
df_merged.shape
# Out:
# (77, 18)

# %%
df_merged.to_csv('df_merged.csv')

# %% [markdown]
# # Develop descriptive statistics

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df_neighb_level = pd.read_csv('df_merged.csv')
del df_neighb_level['Unnamed: 0']
#df_neighb_level
df_tweet_level = pd.read_csv('df_wCompound.csv')  # this contains all of the neutral tweets, remove this
del df_tweet_level['Unnamed: 0']
del df_tweet_level['Unnamed: 0.1']
#df_tweet_level

# %%
# remove all tweets that score neutral in terms of compound sentiment score
df_tweet_level = df_tweet_level[df_tweet_level['Compound Sentiment Score'] != 0]
#df_tweet_level[df_tweet_level['Compound Sentiment Score'] == 0]

# %%
print(df_tweet_level.columns)
print(df_neighb_level.columns)
# Out:
# Index(['Community Area Mentioned', 'Tweet Content', 'Tweet Coordinates',
#        'Tweet Day and Time', 'Tweet Number of Times Liked',
#        'Tweet Number of Times Retweeted', 'User Location',
#        'User Number of Followers', 'User Screen Name', 'Sentiment',
#        'Compound Sentiment Score'],
#       dtype='object')
# Index(['Community Area Number', 'COMMUNITY AREA NAME',
#        'PERCENT OF HOUSING CROWDED', 'PERCENT HOUSEHOLDS BELOW POVERTY',
#        'PERCENT AGED 16+ UNEMPLOYED',
#        'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
#        'PERCENT AGED UNDER 18 OR OVER 64', 'PER CAPITA INCOME ',
#        'HARDSHIP INDEX', 'Sum Negative Tweet Sentiment',
#        'Sum Positive Tweet Sentiment', 'Total Number of Negative Tweets',
#        'Total Number of Positive Tweets',
#        'Total Number of Positive and Negative Tweets',
#        'Average Negative Sentiment', 'Average Positive Sentiment',
#        'Unweighted Reputation Score', 'Weighted Reputation Score'],
#       dtype='object')

# %%
# show basic descriptives stats per neighborhood and per variable 
a = df_tweet_level.groupby('Community Area Mentioned')
# can also use a.mean() and a.std() to examine just mean or standard deviation

b = df_neighb_level.groupby('COMMUNITY AREA NAME')
# b.mean() and b.std()

a.describe()
b.describe()
# Out:
#                                 Compound Sentiment Score  \
# Community Area Mentioned
# albany park              count  34.000000
#                          mean   0.120500
#                          std    0.474977
#                          min   -0.735100
#                          25%   -0.340000
#                          50%    0.283200
#                          75%    0.560600
#                          max    0.803400
# archer heights           count  1.000000
#                          mean   0.557400
#                          std   NaN
#                          min    0.557400
#                          25%    0.557400
#                          50%    0.557400
#                          75%    0.557400
#                          max    0.557400
# ashburn                  count  43.000000
#                          mean  -0.118872
#                          std    0.404982
#                          min   -0.952400
#                          25%   -0.401900
#                          50%   -0.273200
#                          75%    0.222850
#                          max    0.778300
# auburn gresham           count  19.000000
#                          mean  -0.252105
#                          std    0.358420
#                          min   -0.557400
#                          25%   -0.557400
#                          50%   -0.177900
# ...                                  ...
# west pullman             std    0.475447
#                          min   -0.612400
#                          25%   -0.401900
#                          50%   -0.401900
#                          75%    0.487525
#                          max    0.611400
# west ridge               count  31.000000
#                          mean   0.311210
#                          std    0.571706
#                          min   -0.812600
#                          25%    0.361200
#                          50%    0.585900
#                          75%    0.636900
#                          max    0.875000
# west town                count  54.000000
#                          mean   0.431337
#                          std    0.346244
#                          min   -0.765000
#                          25%    0.401900
#                          50%    0.458100
#                          75%    0.628900
#                          max    0.902200
# woodlawn                 count  57.000000
#                          mean   0.401949
#                          std    0.385990
#                          min   -0.439100
#                          25%    0.318200
#                          50%    0.440400
#                          75%    0.765000
#                          max    0.902000
#
#                                 Tweet Number of Times Liked  \
# Community Area Mentioned
# albany park              count  34.000000
#                          mean   0.352941
#                          std    0.645842
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    0.750000
#                          max    2.000000
# archer heights           count  1.000000
#                          mean   1.000000
#                          std   NaN
#                          min    1.000000
#                          25%    1.000000
#                          50%    1.000000
#                          75%    1.000000
#                          max    1.000000
# ashburn                  count  43.000000
#                          mean   0.069767
#                          std    0.457496
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    0.000000
#                          max    3.000000
# auburn gresham           count  19.000000
#                          mean   0.473684
#                          std    0.841191
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
# ...                                  ...
# west pullman             std    0.250000
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    0.000000
#                          max    1.000000
# west ridge               count  31.000000
#                          mean   0.870968
#                          std    1.607108
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    1.000000
#                          max    6.000000
# west town                count  54.000000
#                          mean   0.703704
#                          std    2.507571
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    0.000000
#                          max    14.000000
# woodlawn                 count  57.000000
#                          mean   0.824561
#                          std    2.188630
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    0.000000
#                          max    11.000000
#
#                                 Tweet Number of Times Retweeted  \
# Community Area Mentioned
# albany park              count  34.000000
#                          mean   0.058824
#                          std    0.342997
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    0.000000
#                          max    2.000000
# archer heights           count  1.000000
#                          mean   0.000000
#                          std   NaN
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    0.000000
#                          max    0.000000
# ashburn                  count  43.000000
#                          mean   2608.837209
#                          std    8445.663108
#                          min    0.000000
#                          25%    0.000000
#                          50%    1.000000
#                          75%    54.500000
#                          max    35482.000000
# auburn gresham           count  19.000000
#                          mean   0.842105
#                          std    1.258887
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
# ...                                  ...
# west pullman             std    0.000000
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    0.000000
#                          max    0.000000
# west ridge               count  31.000000
#                          mean   0.967742
#                          std    1.016001
#                          min    0.000000
#                          25%    0.000000
#                          50%    1.000000
#                          75%    1.000000
#                          max    3.000000
# west town                count  54.000000
#                          mean   1.314815
#                          std    5.692842
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    0.000000
#                          max    41.000000
# woodlawn                 count  57.000000
#                          mean   2.456140
#                          std    6.892206
#                          min    0.000000
#                          25%    0.000000
#                          50%    0.000000
#                          75%    3.000000
#                          max    51.000000
#
#                                 User Number of Followers
# Community Area Mentioned
# albany park              count  34.000000
#                          mean   661.647059
#                          std    873.805605
#                          min    30.000000
#                          25%    157.000000
#                          50%    266.500000
#                          75%    999.000000
#                          max    4512.000000
# archer heights           count  1.000000
#                          mean   46.000000
#                          std   NaN
#                          min    46.000000
#                          25%    46.000000
#                          50%    46.000000
#                          75%    46.000000
#                          max    46.000000
# ashburn                  count  43.000000
#                          mean   3160.325581
#                          std    11900.989814
#                          min    51.000000
#                          25%    114.500000
#                          50%    787.000000
#                          75%    1252.000000
#                          max    76894.000000
# auburn gresham           count  19.000000
#                          mean   7515.315789
#                          std    17464.502970
#                          min    131.000000
#                          25%    262.500000
#                          50%    1743.000000
# ...                                    ...
# west pullman             std    859.977713
#                          min    52.000000
#                          25%    186.250000
#                          50%    229.000000
#                          75%    1252.000000
#                          max    2558.000000
# west ridge               count  31.000000
#                          mean   10051.612903
#                          std    23796.145165
#                          min    18.000000
#                          25%    119.500000
#                          50%    1197.000000
#                          75%    4666.000000
#                          max    87609.000000
# west town                count  54.000000
#                          mean   18415.351852
#                          std    103103.425050
#                          min    11.000000
#                          25%    244.500000
#                          50%    652.500000
#                          75%    2652.500000
#                          max    754571.000000
# woodlawn                 count  57.000000
#                          mean   3480.719298
#                          std    3723.897117
#                          min    16.000000
#                          25%    391.000000
#                          50%    1017.000000
#                          75%    8563.000000
#                          max    12343.000000
#
# [544 rows x 4 columns]

# %% [markdown]
# # Develop inferential statistics

# %% [markdown]
# # Conclusions
